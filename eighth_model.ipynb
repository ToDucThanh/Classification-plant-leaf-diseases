# %%
from tensorflow.keras.layers import Dense, Flatten, BatchNormalization, LayerNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# %%
size = 256
batch_size = 128
epochs = 20
history = {}
def build_model(initializer, optimizer):
    input_shape = (size, size, 3)
    hidden_layer_1 = 1024
    hidden_layer_2 = 512
    num_classes = 39
    layers = [
        Flatten(input_shape=input_shape),
        Dense(hidden_layer_1, kernel_initializer=initializer, activation='relu'),
        LayerNormalization(),
        Dense(hidden_layer_2, kernel_initializer=initializer, activation='relu'),
        LayerNormalization(),
        Dense(num_classes, activation='softmax', kernel_initializer=initializer)
    ]
    model = tf.keras.Sequential(layers)
    model.compile(
    loss='categorical_crossentropy',
    optimizer=optimizer,
    metrics=['accuracy']
    )
    return model

# %%
optim = {}
sgd_momentum = tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9, nesterov=False)
optim['sgd_momentum'] = sgd_momentum
adam = tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07)
optim['adam'] = adam
initializer = tf.keras.initializers.HeNormal()

# %%
train_path = '../input/traindata/train_aug'
test_path = '../input/testdata/test'
train_gen = ImageDataGenerator(rescale=1./255, vertical_flip=True, brightness_range=((0.2, 0.8)))
test_gen = ImageDataGenerator(rescale=1./255)
train_generator = train_gen.flow_from_directory(train_path,     
    target_size = (size, size),
    shuffle=True, 
    batch_size=batch_size
)
valid_generator = test_gen.flow_from_directory(test_path,     
    target_size = (size, size),
    shuffle=False, 
    batch_size=batch_size
)
# Out:
# Found 53164 images belonging to 39 classes.
# Found 11104 images belonging to 39 classes.

# %%
def train_model(k, v):
    model = build_model(initializer, v)
    model.summary()
    print('This is a model using:', k)
    model_save = ModelCheckpoint('./ANN_LN' + k + '.h5',
                                 save_best_only = True, 
                                 save_weights_only = False,
                                 monitor = 'val_loss', 
                                 mode = 'min', verbose = 1)
    milestone = model.fit(train_generator,
              validation_data=valid_generator,
              epochs=epochs,
              steps_per_epoch=train_generator.n//train_generator.batch_size,
              validation_steps = valid_generator.n//valid_generator.batch_size,
              callbacks = [model_save, early_stop, reduce_lr]
              )
    history[k] = milestone

# %%
early_stop = EarlyStopping(monitor = 'val_loss', min_delta = 0.001, 
                               patience = 5, mode = 'min', verbose = 1,
                               restore_best_weights = True)
reduce_lr = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.2, 
                                      patience = 2, min_delta = 0.001, 
                                      mode = 'min', verbose = 1)

for k, v in optim.items():
    train_model(k, v)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 196608)            0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              201327616
# _________________________________________________________________
# layer_normalization (LayerNo (None, 1024)              2048
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# layer_normalization_1 (Layer (None, 512)               1024
# _________________________________________________________________
# dense_2 (Dense)              (None, 39)                20007
# =================================================================
# Total params: 201,875,495
# Trainable params: 201,875,495
# Non-trainable params: 0
# _________________________________________________________________
# This is a model using: sgd_momentum
# Epoch 1/20
# 415/415 [==============================] - 727s 2s/step - loss: 3.3249 - accuracy: 0.1799 - val_loss: 2.0923 - val_accuracy: 0.4367
#
# Epoch 00001: val_loss improved from inf to 2.09231, saving model to ./ANN_LNsgd_momentum.h5
# Epoch 2/20
# 415/415 [==============================] - 326s 785ms/step - loss: 2.0610 - accuracy: 0.4207 - val_loss: 1.6726 - val_accuracy: 0.5195
#
# Epoch 00002: val_loss improved from 2.09231 to 1.67260, saving model to ./ANN_LNsgd_momentum.h5
# Epoch 3/20
# 415/415 [==============================] - 326s 786ms/step - loss: 1.7110 - accuracy: 0.5050 - val_loss: 1.4820 - val_accuracy: 0.5612
#
# Epoch 00003: val_loss improved from 1.67260 to 1.48202, saving model to ./ANN_LNsgd_momentum.h5
# Epoch 4/20
# 415/415 [==============================] - 346s 834ms/step - loss: 1.4973 - accuracy: 0.5623 - val_loss: 1.3464 - val_accuracy: 0.6127
#
# Epoch 00004: val_loss improved from 1.48202 to 1.34641, saving model to ./ANN_LNsgd_momentum.h5
# Epoch 5/20
# 415/415 [==============================] - 342s 824ms/step - loss: 1.3651 - accuracy: 0.5952 - val_loss: 1.2536 - val_accuracy: 0.6348
#
# Epoch 00005: val_loss improved from 1.34641 to 1.25364, saving model to ./ANN_LNsgd_momentum.h5
# Epoch 6/20
# 415/415 [==============================] - 349s 841ms/step - loss: 1.2532 - accuracy: 0.6270 - val_loss: 1.1733 - val_accuracy: 0.6580
#
# Epoch 00006: val_loss improved from 1.25364 to 1.17326, saving model to ./ANN_LNsgd_momentum.h5
# Epoch 7/20
# 415/415 [==============================] - 342s 825ms/step - loss: 1.1753 - accuracy: 0.6505 - val_loss: 1.1367 - val_accuracy: 0.6618
#
# Epoch 00007: val_loss improved from 1.17326 to 1.13672, saving model to ./ANN_LNsgd_momentum.h5
# Epoch 8/20
# 415/415 [==============================] - 344s 827ms/step - loss: 1.1062 - accuracy: 0.6685 - val_loss: 1.0334 - val_accuracy: 0.6830
#
# Epoch 00008: val_loss improved from 1.13672 to 1.03340, saving model to ./ANN_LNsgd_momentum.h5
# Epoch 9/20
# 415/415 [==============================] - 346s 835ms/step - loss: 1.0215 - accuracy: 0.6913 - val_loss: 0.9404 - val_accuracy: 0.7127
#
# Epoch 00009: val_loss improved from 1.03340 to 0.94038, saving model to ./ANN_LNsgd_momentum.h5
# Epoch 10/20
# 415/415 [==============================] - 365s 880ms/step - loss: 0.9815 - accuracy: 0.7016 - val_loss: 0.9342 - val_accuracy: 0.7174
#
# Epoch 00010: val_loss improved from 0.94038 to 0.93419, saving model to ./ANN_LNsgd_momentum.h5
# Epoch 11/20
# 415/415 [==============================] - 352s 848ms/step - loss: 0.9383 - accuracy: 0.7146 - val_loss: 0.9296 - val_accuracy: 0.7206
#
# Epoch 00011: val_loss improved from 0.93419 to 0.92959, saving model to ./ANN_LNsgd_momentum.h5
# Epoch 12/20
# 415/415 [==============================] - 351s 846ms/step - loss: 0.8850 - accuracy: 0.7277 - val_loss: 0.9096 - val_accuracy: 0.7186
#
# Epoch 00012: val_loss improved from 0.92959 to 0.90956, saving model to ./ANN_LNsgd_momentum.h5
# Epoch 13/20
# 415/415 [==============================] - 353s 851ms/step - loss: 0.8721 - accuracy: 0.7346 - val_loss: 0.8176 - val_accuracy: 0.7522
#
# Epoch 00013: val_loss improved from 0.90956 to 0.81755, saving model to ./ANN_LNsgd_momentum.h5
# Epoch 14/20
# 415/415 [==============================] - 350s 844ms/step - loss: 0.8053 - accuracy: 0.7544 - val_loss: 0.8318 - val_accuracy: 0.7439
#
# Epoch 00014: val_loss did not improve from 0.81755
# Epoch 15/20
# 415/415 [==============================] - 343s 826ms/step - loss: 0.7843 - accuracy: 0.7604 - val_loss: 0.7833 - val_accuracy: 0.7572
#
# Epoch 00015: val_loss improved from 0.81755 to 0.78329, saving model to ./ANN_LNsgd_momentum.h5
# Epoch 16/20
# 415/415 [==============================] - 364s 878ms/step - loss: 0.7445 - accuracy: 0.7694 - val_loss: 0.8271 - val_accuracy: 0.7464
#
# Epoch 00016: val_loss did not improve from 0.78329
# Epoch 17/20
# 415/415 [==============================] - 361s 870ms/step - loss: 0.7311 - accuracy: 0.7774 - val_loss: 0.7649 - val_accuracy: 0.7632
#
# Epoch 00017: val_loss improved from 0.78329 to 0.76488, saving model to ./ANN_LNsgd_momentum.h5
# Epoch 18/20
# 415/415 [==============================] - 349s 839ms/step - loss: 0.6930 - accuracy: 0.7883 - val_loss: 0.7642 - val_accuracy: 0.7633
#
# Epoch 00018: val_loss improved from 0.76488 to 0.76420, saving model to ./ANN_LNsgd_momentum.h5
# Epoch 19/20
# 415/415 [==============================] - 350s 843ms/step - loss: 0.6902 - accuracy: 0.7868 - val_loss: 0.7511 - val_accuracy: 0.7683
#
# Epoch 00019: val_loss improved from 0.76420 to 0.75109, saving model to ./ANN_LNsgd_momentum.h5
# Epoch 20/20
# 415/415 [==============================] - 350s 843ms/step - loss: 0.6581 - accuracy: 0.7955 - val_loss: 0.7227 - val_accuracy: 0.7774
#
# Epoch 00020: val_loss improved from 0.75109 to 0.72270, saving model to ./ANN_LNsgd_momentum.h5
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 196608)            0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              201327616
# _________________________________________________________________
# layer_normalization_2 (Layer (None, 1024)              2048
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               524800
# _________________________________________________________________
# layer_normalization_3 (Layer (None, 512)               1024
# _________________________________________________________________
# dense_5 (Dense)              (None, 39)                20007
# =================================================================
# Total params: 201,875,495
# Trainable params: 201,875,495
# Non-trainable params: 0
# _________________________________________________________________
# This is a model using: adam
# Epoch 1/20
# 415/415 [==============================] - 347s 835ms/step - loss: 3.2701 - accuracy: 0.1671 - val_loss: 2.1293 - val_accuracy: 0.3997
#
# Epoch 00001: val_loss improved from inf to 2.12933, saving model to ./ANN_LNadam.h5
# Epoch 2/20
# 415/415 [==============================] - 364s 878ms/step - loss: 2.0971 - accuracy: 0.4022 - val_loss: 1.5975 - val_accuracy: 0.5426
#
# Epoch 00002: val_loss improved from 2.12933 to 1.59750, saving model to ./ANN_LNadam.h5
# Epoch 3/20
# 415/415 [==============================] - 368s 888ms/step - loss: 1.6123 - accuracy: 0.5194 - val_loss: 1.3568 - val_accuracy: 0.5912
#
# Epoch 00003: val_loss improved from 1.59750 to 1.35682, saving model to ./ANN_LNadam.h5
# Epoch 4/20
# 415/415 [==============================] - 357s 862ms/step - loss: 1.3688 - accuracy: 0.5818 - val_loss: 1.1163 - val_accuracy: 0.6570
#
# Epoch 00004: val_loss improved from 1.35682 to 1.11629, saving model to ./ANN_LNadam.h5
# Epoch 5/20
# 415/415 [==============================] - 347s 837ms/step - loss: 1.1862 - accuracy: 0.6378 - val_loss: 1.0132 - val_accuracy: 0.6878
#
# Epoch 00005: val_loss improved from 1.11629 to 1.01316, saving model to ./ANN_LNadam.h5
# Epoch 6/20
# 415/415 [==============================] - 347s 836ms/step - loss: 1.0629 - accuracy: 0.6735 - val_loss: 0.9542 - val_accuracy: 0.7071
#
# Epoch 00006: val_loss improved from 1.01316 to 0.95417, saving model to ./ANN_LNadam.h5
# Epoch 7/20
# 415/415 [==============================] - 349s 840ms/step - loss: 1.0155 - accuracy: 0.6884 - val_loss: 0.9064 - val_accuracy: 0.7234
#
# Epoch 00007: val_loss improved from 0.95417 to 0.90644, saving model to ./ANN_LNadam.h5
# Epoch 8/20
# 415/415 [==============================] - 347s 837ms/step - loss: 0.9481 - accuracy: 0.7044 - val_loss: 0.8696 - val_accuracy: 0.7309
#
# Epoch 00008: val_loss improved from 0.90644 to 0.86956, saving model to ./ANN_LNadam.h5
# Epoch 9/20
# 415/415 [==============================] - 354s 854ms/step - loss: 0.8833 - accuracy: 0.7243 - val_loss: 0.8902 - val_accuracy: 0.7292
#
# Epoch 00009: val_loss did not improve from 0.86956
# Epoch 10/20
# 415/415 [==============================] - 338s 815ms/step - loss: 0.8438 - accuracy: 0.7361 - val_loss: 0.8614 - val_accuracy: 0.7352
#
# Epoch 00010: val_loss improved from 0.86956 to 0.86140, saving model to ./ANN_LNadam.h5
# Epoch 11/20
# 415/415 [==============================] - 360s 867ms/step - loss: 0.8008 - accuracy: 0.7469 - val_loss: 0.8165 - val_accuracy: 0.7512
#
# Epoch 00011: val_loss improved from 0.86140 to 0.81654, saving model to ./ANN_LNadam.h5
# Epoch 12/20
# 415/415 [==============================] - 354s 854ms/step - loss: 0.7599 - accuracy: 0.7598 - val_loss: 0.7305 - val_accuracy: 0.7701
#
# Epoch 00012: val_loss improved from 0.81654 to 0.73050, saving model to ./ANN_LNadam.h5
# Epoch 13/20
# 415/415 [==============================] - 365s 879ms/step - loss: 0.7089 - accuracy: 0.7759 - val_loss: 0.7310 - val_accuracy: 0.7719
#
# Epoch 00013: val_loss did not improve from 0.73050
# Epoch 14/20
# 415/415 [==============================] - 341s 822ms/step - loss: 0.6924 - accuracy: 0.7813 - val_loss: 0.7372 - val_accuracy: 0.7671
#
# Epoch 00014: val_loss did not improve from 0.73050
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 15/20
# 415/415 [==============================] - 342s 823ms/step - loss: 0.5562 - accuracy: 0.8247 - val_loss: 0.6043 - val_accuracy: 0.8100
#
# Epoch 00015: val_loss improved from 0.73050 to 0.60427, saving model to ./ANN_LNadam.h5
# Epoch 16/20
# 415/415 [==============================] - 376s 906ms/step - loss: 0.5185 - accuracy: 0.8360 - val_loss: 0.5945 - val_accuracy: 0.8122
#
# Epoch 00016: val_loss improved from 0.60427 to 0.59453, saving model to ./ANN_LNadam.h5
# Epoch 17/20
# 415/415 [==============================] - 354s 854ms/step - loss: 0.5089 - accuracy: 0.8392 - val_loss: 0.5954 - val_accuracy: 0.8149
#
# Epoch 00017: val_loss did not improve from 0.59453
# Epoch 18/20
# 415/415 [==============================] - 338s 815ms/step - loss: 0.4955 - accuracy: 0.8431 - val_loss: 0.5914 - val_accuracy: 0.8157
#
# Epoch 00018: val_loss improved from 0.59453 to 0.59143, saving model to ./ANN_LNadam.h5
# Epoch 19/20
# 415/415 [==============================] - 376s 906ms/step - loss: 0.4991 - accuracy: 0.8408 - val_loss: 0.6078 - val_accuracy: 0.8081
#
# Epoch 00019: val_loss did not improve from 0.59143
# Epoch 20/20
# 415/415 [==============================] - 362s 873ms/step - loss: 0.4715 - accuracy: 0.8496 - val_loss: 0.5945 - val_accuracy: 0.8145
#
# Epoch 00020: val_loss did not improve from 0.59143
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.

# %%
#Drawing
plt.subplot(4, 1, 1)
plt.title('Training loss')
plt.xlabel('Epoch')

plt.subplot(4, 1, 2)
plt.title('Validation loss')
plt.xlabel('Epoch')

plt.subplot(4, 1, 3)
plt.title('Training accuracy')
plt.xlabel('Epoch')

plt.subplot(4, 1, 4)
plt.title('Validation accuracy')
plt.xlabel('Epoch')

for update_rule, milestone in history.items():
    plt.subplot(4, 1, 1)
    plt.plot(milestone.history['loss'], 'o', label=update_rule)

    plt.subplot(4, 1, 2)
    plt.plot(milestone.history['val_loss'], 'o', label=update_rule)
    plt.subplot(4, 1, 3)
    plt.plot(milestone.history['accuracy'], '-o', label=update_rule)
    
    plt.subplot(4, 1, 4)
    plt.plot(milestone.history['val_accuracy'], '-o', label=update_rule)

for i in [1, 2, 3, 4]:
    plt.subplot(4, 1, i)
    plt.legend(loc='upper center', ncol=4)
plt.gcf().set_size_inches(20, 20)
plt.show()
