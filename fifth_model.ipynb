# %%
from tensorflow.keras.layers import Input, Dense, Flatten, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# %%
size = 256
batch_size = 128
epochs = 20
history = {}
def build_model(initializer, optimizer):
    input_shape = (size, size, 3)
    hidden_layer_1 = 1024
    hidden_layer_2 = 512
    num_classes = 39
    layers = [
        Flatten(input_shape=input_shape),
        BatchNormalization(),
        Dense(hidden_layer_1, activation='relu', kernel_initializer=initializer),
        BatchNormalization(),
        Dense(hidden_layer_2, activation='relu', kernel_initializer=initializer),
        BatchNormalization(),
        Dense(num_classes, activation='softmax', kernel_initializer=initializer)
    ]
    model = tf.keras.Sequential(layers)
    model.compile(
    loss='categorical_crossentropy',
    optimizer=optimizer,
    metrics=['accuracy']
    )
    return model

# %%
optim = {}
sgd_momentum = tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9, nesterov=False)
optim['sgd_momentum'] = sgd_momentum
adam = tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07)
optim['adam'] = adam
initializer = tf.keras.initializers.HeNormal()

# %%
train_path = '../input/traindata/train_aug'
test_path = '../input/testdata/test'
gen = ImageDataGenerator(rescale=1./255)
train_generator = gen.flow_from_directory(train_path,     
    target_size = (size, size),
    shuffle=True, 
    batch_size=batch_size
)
valid_generator = gen.flow_from_directory(test_path,     
    target_size = (size, size),
    shuffle=False, 
    batch_size=batch_size
)
# Out:
# Found 53164 images belonging to 39 classes.
# Found 11104 images belonging to 39 classes.

# %%
def train_model(k, v):
    model = build_model(initializer, v)
    model.summary()
    print('This is a model using:', k)
    model_save = ModelCheckpoint('./ANN_BN_after_activation_' + k + '.h5',
                                 save_best_only = True, 
                                 save_weights_only = False,
                                 monitor = 'val_loss', 
                                 mode = 'min', verbose = 1)
    milestone = model.fit(train_generator,
              validation_data=valid_generator,
              epochs=epochs,
              steps_per_epoch=train_generator.n//train_generator.batch_size - 1,
              validation_steps = valid_generator.n//valid_generator.batch_size,
              callbacks = [model_save, early_stop, reduce_lr]
              )
    history[k] = milestone

# %%
early_stop = EarlyStopping(monitor = 'val_loss', min_delta = 0.001, 
                               patience = 5, mode = 'min', verbose = 1,
                               restore_best_weights = True)
reduce_lr = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.2, 
                                      patience = 2, min_delta = 0.001, 
                                      mode = 'min', verbose = 1)

for k, v in optim.items():
    train_model(k, v)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 196608)            0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 196608)            786432
# _________________________________________________________________
# dense (Dense)                (None, 1024)              201327616
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 1024)              4096
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 512)               2048
# _________________________________________________________________
# dense_2 (Dense)              (None, 39)                20007
# =================================================================
# Total params: 202,664,999
# Trainable params: 202,268,711
# Non-trainable params: 396,288
# _________________________________________________________________
# This is a model using: sgd_momentum
# Epoch 1/20
# 414/414 [==============================] - 382s 921ms/step - loss: 1.7095 - accuracy: 0.5510 - val_loss: 0.9028 - val_accuracy: 0.7552
#
# Epoch 00001: val_loss improved from inf to 0.90283, saving model to ./ANN_BN_after_activation_sgd_momentum.h5
# Epoch 2/20
# 414/414 [==============================] - 287s 694ms/step - loss: 0.6441 - accuracy: 0.8274 - val_loss: 0.6868 - val_accuracy: 0.7997
#
# Epoch 00002: val_loss improved from 0.90283 to 0.68683, saving model to ./ANN_BN_after_activation_sgd_momentum.h5
# Epoch 3/20
# 414/414 [==============================] - 278s 672ms/step - loss: 0.3913 - accuracy: 0.9079 - val_loss: 0.6220 - val_accuracy: 0.8196
#
# Epoch 00003: val_loss improved from 0.68683 to 0.62199, saving model to ./ANN_BN_after_activation_sgd_momentum.h5
# Epoch 4/20
# 414/414 [==============================] - 281s 679ms/step - loss: 0.2302 - accuracy: 0.9565 - val_loss: 0.6037 - val_accuracy: 0.8230
#
# Epoch 00004: val_loss improved from 0.62199 to 0.60372, saving model to ./ANN_BN_after_activation_sgd_momentum.h5
# Epoch 5/20
# 414/414 [==============================] - 291s 704ms/step - loss: 0.1368 - accuracy: 0.9815 - val_loss: 0.5881 - val_accuracy: 0.8232
#
# Epoch 00005: val_loss improved from 0.60372 to 0.58811, saving model to ./ANN_BN_after_activation_sgd_momentum.h5
# Epoch 6/20
# 414/414 [==============================] - 289s 699ms/step - loss: 0.0846 - accuracy: 0.9924 - val_loss: 0.5713 - val_accuracy: 0.8315
#
# Epoch 00006: val_loss improved from 0.58811 to 0.57128, saving model to ./ANN_BN_after_activation_sgd_momentum.h5
# Epoch 7/20
# 414/414 [==============================] - 286s 691ms/step - loss: 0.0551 - accuracy: 0.9970 - val_loss: 0.5804 - val_accuracy: 0.8290
#
# Epoch 00007: val_loss did not improve from 0.57128
# Epoch 8/20
# 414/414 [==============================] - 283s 685ms/step - loss: 0.0363 - accuracy: 0.9986 - val_loss: 0.5796 - val_accuracy: 0.8328
#
# Epoch 00008: val_loss did not improve from 0.57128
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 9/20
# 414/414 [==============================] - 307s 742ms/step - loss: 0.0256 - accuracy: 0.9997 - val_loss: 0.5462 - val_accuracy: 0.8417
#
# Epoch 00009: val_loss improved from 0.57128 to 0.54624, saving model to ./ANN_BN_after_activation_sgd_momentum.h5
# Epoch 10/20
# 414/414 [==============================] - 260s 627ms/step - loss: 0.0200 - accuracy: 0.9998 - val_loss: 0.5491 - val_accuracy: 0.8420
#
# Epoch 00010: val_loss did not improve from 0.54624
# Epoch 11/20
# 414/414 [==============================] - 237s 573ms/step - loss: 0.0191 - accuracy: 0.9999 - val_loss: 0.5520 - val_accuracy: 0.8414
#
# Epoch 00011: val_loss did not improve from 0.54624
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 12/20
# 414/414 [==============================] - 233s 562ms/step - loss: 0.0180 - accuracy: 0.9997 - val_loss: 0.5504 - val_accuracy: 0.8421
#
# Epoch 00012: val_loss did not improve from 0.54624
# Epoch 13/20
# 414/414 [==============================] - 235s 567ms/step - loss: 0.0176 - accuracy: 1.0000 - val_loss: 0.5493 - val_accuracy: 0.8423
#
# Epoch 00013: val_loss did not improve from 0.54624
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 14/20
# 414/414 [==============================] - 237s 571ms/step - loss: 0.0174 - accuracy: 0.9999 - val_loss: 0.5496 - val_accuracy: 0.8419
#
# Epoch 00014: val_loss did not improve from 0.54624
# Restoring model weights from the end of the best epoch.
# Epoch 00014: early stopping
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 196608)            0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 196608)            786432
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              201327616
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 1024)              4096
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               524800
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# dense_5 (Dense)              (None, 39)                20007
# =================================================================
# Total params: 202,664,999
# Trainable params: 202,268,711
# Non-trainable params: 396,288
# _________________________________________________________________
# This is a model using: adam
# Epoch 1/20
# 414/414 [==============================] - 234s 564ms/step - loss: 1.8053 - accuracy: 0.5133 - val_loss: 0.8585 - val_accuracy: 0.7417
#
# Epoch 00001: val_loss improved from inf to 0.85845, saving model to ./ANN_BN_after_activation_adam.h5
# Epoch 2/20
# 414/414 [==============================] - 272s 656ms/step - loss: 0.6959 - accuracy: 0.7849 - val_loss: 0.6214 - val_accuracy: 0.8053
#
# Epoch 00002: val_loss improved from 0.85845 to 0.62139, saving model to ./ANN_BN_after_activation_adam.h5
# Epoch 3/20
# 414/414 [==============================] - 246s 595ms/step - loss: 0.4370 - accuracy: 0.8629 - val_loss: 0.5833 - val_accuracy: 0.8175
#
# Epoch 00003: val_loss improved from 0.62139 to 0.58334, saving model to ./ANN_BN_after_activation_adam.h5
# Epoch 4/20
# 414/414 [==============================] - 247s 596ms/step - loss: 0.2959 - accuracy: 0.9049 - val_loss: 0.5634 - val_accuracy: 0.8284
#
# Epoch 00004: val_loss improved from 0.58334 to 0.56341, saving model to ./ANN_BN_after_activation_adam.h5
# Epoch 5/20
# 414/414 [==============================] - 246s 594ms/step - loss: 0.2078 - accuracy: 0.9337 - val_loss: 0.5688 - val_accuracy: 0.8348
#
# Epoch 00005: val_loss did not improve from 0.56341
# Epoch 6/20
# 414/414 [==============================] - 238s 573ms/step - loss: 0.1558 - accuracy: 0.9500 - val_loss: 0.5706 - val_accuracy: 0.8350
#
# Epoch 00006: val_loss did not improve from 0.56341
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 7/20
# 414/414 [==============================] - 273s 659ms/step - loss: 0.0775 - accuracy: 0.9789 - val_loss: 0.4146 - val_accuracy: 0.8813
#
# Epoch 00007: val_loss improved from 0.56341 to 0.41463, saving model to ./ANN_BN_after_activation_adam.h5
# Epoch 8/20
# 414/414 [==============================] - 259s 626ms/step - loss: 0.0300 - accuracy: 0.9954 - val_loss: 0.4150 - val_accuracy: 0.8806
#
# Epoch 00008: val_loss did not improve from 0.41463
# Epoch 9/20
# 414/414 [==============================] - 291s 702ms/step - loss: 0.0196 - accuracy: 0.9982 - val_loss: 0.4223 - val_accuracy: 0.8821
#
# Epoch 00009: val_loss did not improve from 0.41463
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 10/20
# 414/414 [==============================] - 302s 728ms/step - loss: 0.0141 - accuracy: 0.9990 - val_loss: 0.4112 - val_accuracy: 0.8834
#
# Epoch 00010: val_loss improved from 0.41463 to 0.41125, saving model to ./ANN_BN_after_activation_adam.h5
# Epoch 11/20
# 414/414 [==============================] - 298s 721ms/step - loss: 0.0115 - accuracy: 0.9994 - val_loss: 0.4108 - val_accuracy: 0.8842
#
# Epoch 00011: val_loss improved from 0.41125 to 0.41077, saving model to ./ANN_BN_after_activation_adam.h5
# Epoch 12/20
# 414/414 [==============================] - 304s 734ms/step - loss: 0.0105 - accuracy: 0.9995 - val_loss: 0.4123 - val_accuracy: 0.8839
#
# Epoch 00012: val_loss did not improve from 0.41077
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 13/20
# 414/414 [==============================] - 272s 657ms/step - loss: 0.0099 - accuracy: 0.9995 - val_loss: 0.4111 - val_accuracy: 0.8855
#
# Epoch 00013: val_loss did not improve from 0.41077
# Epoch 14/20
# 414/414 [==============================] - 260s 627ms/step - loss: 0.0088 - accuracy: 0.9997 - val_loss: 0.4114 - val_accuracy: 0.8854
#
# Epoch 00014: val_loss did not improve from 0.41077
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# Epoch 15/20
# 414/414 [==============================] - 234s 566ms/step - loss: 0.0090 - accuracy: 0.9997 - val_loss: 0.4113 - val_accuracy: 0.8855
#
# Epoch 00015: val_loss did not improve from 0.41077
# Restoring model weights from the end of the best epoch.
# Epoch 00015: early stopping

# %%
#Drawing
plt.subplot(4, 1, 1)
plt.title('Training loss')
plt.xlabel('Epoch')

plt.subplot(4, 1, 2)
plt.title('Validation loss')
plt.xlabel('Epoch')

plt.subplot(4, 1, 3)
plt.title('Training accuracy')
plt.xlabel('Epoch')

plt.subplot(4, 1, 4)
plt.title('Validation accuracy')
plt.xlabel('Epoch')

for update_rule, milestone in history.items():
    plt.subplot(4, 1, 1)
    plt.plot(milestone.history['loss'], 'o', label=update_rule)

    plt.subplot(4, 1, 2)
    plt.plot(milestone.history['val_loss'], 'o', label=update_rule)
    plt.subplot(4, 1, 3)
    plt.plot(milestone.history['accuracy'], '-o', label=update_rule)
    
    plt.subplot(4, 1, 4)
    plt.plot(milestone.history['val_accuracy'], '-o', label=update_rule)

for i in [1, 2, 3, 4]:
    plt.subplot(4, 1, i)
    plt.legend(loc='upper center', ncol=4)
plt.gcf().set_size_inches(20, 20)
plt.show()
