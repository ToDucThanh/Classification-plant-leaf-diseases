# %%
from tensorflow.keras.layers import Input, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import tensorflow as tf

# %%
size = 256
batch_size = 128
epochs = 22
history = {}
def build_model(initializer, optimizer):
    input_shape = (size, size, 3)
    hidden_layer_1 = 1024
    hidden_layer_2 = 512
    num_classes = 39
    layers = [
        Flatten(input_shape=input_shape),
        Dense(hidden_layer_1, activation='relu', kernel_initializer=initializer),
        Dense(hidden_layer_2, activation='relu', kernel_initializer=initializer),
        Dense(num_classes, activation='softmax', kernel_initializer=initializer)
    ]
    model = tf.keras.Sequential(layers)
    model.compile(
    loss='categorical_crossentropy',
    optimizer=optimizer,
    metrics=['accuracy']
    )
    return model

# %%
optim = {}
sgd = tf.keras.optimizers.SGD(learning_rate=0.001)
optim['sgd'] = sgd
sgd_momentum = tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9, nesterov=False)
optim['sgd_momentum'] = sgd_momentum
rmsprop = tf.keras.optimizers.RMSprop(
    learning_rate=0.001, rho=0.9, momentum=0.0, epsilon=1e-07)
optim['rmsprop'] = rmsprop
adam = tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07)
optim['adam'] = adam
initializer = tf.keras.initializers.HeNormal()

# %%
train_path = '../input/official-leaf/train_aug'
test_path = '../input/official-test/test'
gen = ImageDataGenerator(rescale=1./255)
train_generator = gen.flow_from_directory(train_path,     
    target_size = (size, size),
    shuffle=True, 
    batch_size=batch_size
)
valid_generator = gen.flow_from_directory(test_path,     
    target_size = (size, size),
    shuffle=False, 
    batch_size=batch_size
)
# Out:
# Found 53164 images belonging to 39 classes.
# Found 11104 images belonging to 39 classes.

# %%
def train_model(k, v):
    model = build_model(initializer, v)
    model.summary()
    print('This is a model using:', k)
    print()
    model_save = ModelCheckpoint('./ANN_official_He_init_' + k + '.h5',
                                 save_best_only = True, 
                                 save_weights_only = False,
                                 monitor = 'val_loss', 
                                 mode = 'min', verbose = 1)

    print('model using:', k)
    print()
    milestones = model.fit(train_generator,
              validation_data=valid_generator,
              epochs=epochs,
              steps_per_epoch=train_generator.n//train_generator.batch_size,
              validation_steps = valid_generator.n//valid_generator.batch_size,
              callbacks = [model_save, early_stop, reduce_lr]
              )
    history[k] = milestones

# %%
early_stop = EarlyStopping(monitor = 'val_loss', min_delta = 0.001, 
                               patience = 5, mode = 'min', verbose = 1,
                               restore_best_weights = True)
reduce_lr = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.2, 
                                      patience = 2, min_delta = 0.001, 
                                      mode = 'min', verbose = 1)
for k, v in optim.items():
    train_model(k, v)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 196608)            0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              201327616
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_2 (Dense)              (None, 39)                20007
# =================================================================
# Total params: 201,872,423
# Trainable params: 201,872,423
# Non-trainable params: 0
# _________________________________________________________________
# This is a model using: sgd
#
# model using: sgd
#
# Epoch 1/22
# 415/415 [==============================] - 492s 1s/step - loss: 3.0893 - accuracy: 0.2076 - val_loss: 2.1168 - val_accuracy: 0.4222
#
# Epoch 00001: val_loss improved from inf to 2.11682, saving model to ./ANN_official_He_init_sgd.h5
# Epoch 2/22
# 415/415 [==============================] - 238s 573ms/step - loss: 2.2227 - accuracy: 0.3907 - val_loss: 1.8283 - val_accuracy: 0.5081
#
# Epoch 00002: val_loss improved from 2.11682 to 1.82830, saving model to ./ANN_official_He_init_sgd.h5
# Epoch 3/22
# 415/415 [==============================] - 240s 578ms/step - loss: 1.9192 - accuracy: 0.4656 - val_loss: 1.6192 - val_accuracy: 0.5548
#
# Epoch 00003: val_loss improved from 1.82830 to 1.61921, saving model to ./ANN_official_He_init_sgd.h5
# Epoch 4/22
# 415/415 [==============================] - 273s 657ms/step - loss: 1.7424 - accuracy: 0.5127 - val_loss: 1.6078 - val_accuracy: 0.5468
#
# Epoch 00004: val_loss improved from 1.61921 to 1.60783, saving model to ./ANN_official_He_init_sgd.h5
# Epoch 5/22
# 415/415 [==============================] - 254s 612ms/step - loss: 1.6378 - accuracy: 0.5359 - val_loss: 1.4474 - val_accuracy: 0.5909
#
# Epoch 00005: val_loss improved from 1.60783 to 1.44736, saving model to ./ANN_official_He_init_sgd.h5
# Epoch 6/22
# 415/415 [==============================] - 263s 633ms/step - loss: 1.5225 - accuracy: 0.5627 - val_loss: 1.3705 - val_accuracy: 0.6090
#
# Epoch 00006: val_loss improved from 1.44736 to 1.37050, saving model to ./ANN_official_He_init_sgd.h5
# Epoch 7/22
# 415/415 [==============================] - 258s 621ms/step - loss: 1.4383 - accuracy: 0.5924 - val_loss: 1.3122 - val_accuracy: 0.6335
#
# Epoch 00007: val_loss improved from 1.37050 to 1.31223, saving model to ./ANN_official_He_init_sgd.h5
# Epoch 8/22
# 415/415 [==============================] - 265s 640ms/step - loss: 1.3737 - accuracy: 0.6058 - val_loss: 1.3146 - val_accuracy: 0.6195
#
# Epoch 00008: val_loss did not improve from 1.31223
# Epoch 9/22
# 415/415 [==============================] - 251s 605ms/step - loss: 1.3038 - accuracy: 0.6280 - val_loss: 1.2222 - val_accuracy: 0.6468
#
# Epoch 00009: val_loss improved from 1.31223 to 1.22225, saving model to ./ANN_official_He_init_sgd.h5
# Epoch 10/22
# 415/415 [==============================] - 248s 598ms/step - loss: 1.2690 - accuracy: 0.6384 - val_loss: 1.1940 - val_accuracy: 0.6582
#
# Epoch 00010: val_loss improved from 1.22225 to 1.19402, saving model to ./ANN_official_He_init_sgd.h5
# Epoch 11/22
# 415/415 [==============================] - 243s 585ms/step - loss: 1.2066 - accuracy: 0.6574 - val_loss: 1.1698 - val_accuracy: 0.6700
#
# Epoch 00011: val_loss improved from 1.19402 to 1.16982, saving model to ./ANN_official_He_init_sgd.h5
# Epoch 12/22
# 415/415 [==============================] - 253s 611ms/step - loss: 1.1654 - accuracy: 0.6657 - val_loss: 1.1296 - val_accuracy: 0.6739
#
# Epoch 00012: val_loss improved from 1.16982 to 1.12957, saving model to ./ANN_official_He_init_sgd.h5
# Epoch 13/22
# 415/415 [==============================] - 257s 619ms/step - loss: 1.1358 - accuracy: 0.6732 - val_loss: 1.1523 - val_accuracy: 0.6687
#
# Epoch 00013: val_loss did not improve from 1.12957
# Epoch 14/22
# 415/415 [==============================] - 244s 588ms/step - loss: 1.0868 - accuracy: 0.6882 - val_loss: 1.0992 - val_accuracy: 0.6804
#
# Epoch 00014: val_loss improved from 1.12957 to 1.09916, saving model to ./ANN_official_He_init_sgd.h5
# Epoch 15/22
# 415/415 [==============================] - 252s 607ms/step - loss: 1.0568 - accuracy: 0.6987 - val_loss: 1.0778 - val_accuracy: 0.6845
#
# Epoch 00015: val_loss improved from 1.09916 to 1.07779, saving model to ./ANN_official_He_init_sgd.h5
# Epoch 16/22
# 415/415 [==============================] - 276s 665ms/step - loss: 1.0204 - accuracy: 0.7075 - val_loss: 1.0520 - val_accuracy: 0.6955
#
# Epoch 00016: val_loss improved from 1.07779 to 1.05205, saving model to ./ANN_official_He_init_sgd.h5
# Epoch 17/22
# 415/415 [==============================] - 278s 669ms/step - loss: 0.9947 - accuracy: 0.7156 - val_loss: 1.0385 - val_accuracy: 0.7030
#
# Epoch 00017: val_loss improved from 1.05205 to 1.03845, saving model to ./ANN_official_He_init_sgd.h5
# Epoch 18/22
# 415/415 [==============================] - 283s 682ms/step - loss: 0.9705 - accuracy: 0.7221 - val_loss: 0.9980 - val_accuracy: 0.7142
#
# Epoch 00018: val_loss improved from 1.03845 to 0.99800, saving model to ./ANN_official_He_init_sgd.h5
# Epoch 19/22
# 415/415 [==============================] - 282s 680ms/step - loss: 0.9400 - accuracy: 0.7312 - val_loss: 0.9846 - val_accuracy: 0.7131
#
# Epoch 00019: val_loss improved from 0.99800 to 0.98463, saving model to ./ANN_official_He_init_sgd.h5
# Epoch 20/22
# 415/415 [==============================] - 282s 680ms/step - loss: 0.9218 - accuracy: 0.7347 - val_loss: 1.0270 - val_accuracy: 0.6944
#
# Epoch 00020: val_loss did not improve from 0.98463
# Epoch 21/22
# 415/415 [==============================] - 281s 678ms/step - loss: 0.8988 - accuracy: 0.7406 - val_loss: 0.9614 - val_accuracy: 0.7163
#
# Epoch 00021: val_loss improved from 0.98463 to 0.96138, saving model to ./ANN_official_He_init_sgd.h5
# Epoch 22/22
# 415/415 [==============================] - 277s 667ms/step - loss: 0.8724 - accuracy: 0.7513 - val_loss: 0.9188 - val_accuracy: 0.7346
#
# Epoch 00022: val_loss improved from 0.96138 to 0.91883, saving model to ./ANN_official_He_init_sgd.h5
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 196608)            0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              201327616
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_5 (Dense)              (None, 39)                20007
# =================================================================
# Total params: 201,872,423
# Trainable params: 201,872,423
# Non-trainable params: 0
# _________________________________________________________________
# This is a model using: sgd_momentum
#
# model using: sgd_momentum
#
# Epoch 1/22
# 415/415 [==============================] - 280s 675ms/step - loss: 2.7582 - accuracy: 0.2799 - val_loss: 1.7069 - val_accuracy: 0.4922
#
# Epoch 00001: val_loss improved from inf to 1.70692, saving model to ./ANN_official_He_init_sgd_momentum.h5
# Epoch 2/22
# 415/415 [==============================] - 287s 692ms/step - loss: 1.6717 - accuracy: 0.5190 - val_loss: 1.3498 - val_accuracy: 0.6135
#
# Epoch 00002: val_loss improved from 1.70692 to 1.34982, saving model to ./ANN_official_He_init_sgd_momentum.h5
# Epoch 3/22
# 415/415 [==============================] - 287s 692ms/step - loss: 1.4164 - accuracy: 0.5849 - val_loss: 1.2763 - val_accuracy: 0.6241
#
# Epoch 00003: val_loss improved from 1.34982 to 1.27628, saving model to ./ANN_official_He_init_sgd_momentum.h5
# Epoch 4/22
# 415/415 [==============================] - 289s 696ms/step - loss: 1.2454 - accuracy: 0.6306 - val_loss: 1.0895 - val_accuracy: 0.6790
#
# Epoch 00004: val_loss improved from 1.27628 to 1.08949, saving model to ./ANN_official_He_init_sgd_momentum.h5
# Epoch 5/22
# 415/415 [==============================] - 278s 669ms/step - loss: 1.1177 - accuracy: 0.6639 - val_loss: 1.1321 - val_accuracy: 0.6514
#
# Epoch 00005: val_loss did not improve from 1.08949
# Epoch 6/22
# 415/415 [==============================] - 271s 652ms/step - loss: 1.0145 - accuracy: 0.6921 - val_loss: 0.9470 - val_accuracy: 0.7195
#
# Epoch 00006: val_loss improved from 1.08949 to 0.94697, saving model to ./ANN_official_He_init_sgd_momentum.h5
# Epoch 7/22
# 415/415 [==============================] - 277s 667ms/step - loss: 0.9516 - accuracy: 0.7103 - val_loss: 0.9159 - val_accuracy: 0.7226
#
# Epoch 00007: val_loss improved from 0.94697 to 0.91595, saving model to ./ANN_official_He_init_sgd_momentum.h5
# Epoch 8/22
# 415/415 [==============================] - 277s 667ms/step - loss: 0.8961 - accuracy: 0.7279 - val_loss: 0.8523 - val_accuracy: 0.7438
#
# Epoch 00008: val_loss improved from 0.91595 to 0.85232, saving model to ./ANN_official_He_init_sgd_momentum.h5
# Epoch 9/22
# 415/415 [==============================] - 284s 685ms/step - loss: 0.8087 - accuracy: 0.7532 - val_loss: 0.8422 - val_accuracy: 0.7410
#
# Epoch 00009: val_loss improved from 0.85232 to 0.84221, saving model to ./ANN_official_He_init_sgd_momentum.h5
# Epoch 10/22
# 415/415 [==============================] - 268s 645ms/step - loss: 0.7827 - accuracy: 0.7616 - val_loss: 0.7848 - val_accuracy: 0.7610
#
# Epoch 00010: val_loss improved from 0.84221 to 0.78482, saving model to ./ANN_official_He_init_sgd_momentum.h5
# Epoch 11/22
# 415/415 [==============================] - 275s 664ms/step - loss: 0.7320 - accuracy: 0.7737 - val_loss: 0.8572 - val_accuracy: 0.7364
#
# Epoch 00011: val_loss did not improve from 0.78482
# Epoch 12/22
# 415/415 [==============================] - 273s 657ms/step - loss: 0.6869 - accuracy: 0.7850 - val_loss: 0.7877 - val_accuracy: 0.7539
#
# Epoch 00012: val_loss did not improve from 0.78482
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 13/22
# 415/415 [==============================] - 261s 629ms/step - loss: 0.5828 - accuracy: 0.8258 - val_loss: 0.6791 - val_accuracy: 0.7978
#
# Epoch 00013: val_loss improved from 0.78482 to 0.67910, saving model to ./ANN_official_He_init_sgd_momentum.h5
# Epoch 14/22
# 415/415 [==============================] - 281s 678ms/step - loss: 0.5307 - accuracy: 0.8462 - val_loss: 0.6533 - val_accuracy: 0.8004
#
# Epoch 00014: val_loss improved from 0.67910 to 0.65327, saving model to ./ANN_official_He_init_sgd_momentum.h5
# Epoch 15/22
# 415/415 [==============================] - 280s 674ms/step - loss: 0.5156 - accuracy: 0.8502 - val_loss: 0.6660 - val_accuracy: 0.7968
#
# Epoch 00015: val_loss did not improve from 0.65327
# Epoch 16/22
# 415/415 [==============================] - 256s 618ms/step - loss: 0.5223 - accuracy: 0.8496 - val_loss: 0.6489 - val_accuracy: 0.8011
#
# Epoch 00016: val_loss improved from 0.65327 to 0.64891, saving model to ./ANN_official_He_init_sgd_momentum.h5
# Epoch 17/22
# 415/415 [==============================] - 279s 673ms/step - loss: 0.5020 - accuracy: 0.8558 - val_loss: 0.6581 - val_accuracy: 0.7984
#
# Epoch 00017: val_loss did not improve from 0.64891
# Epoch 18/22
# 415/415 [==============================] - 265s 639ms/step - loss: 0.5027 - accuracy: 0.8545 - val_loss: 0.6425 - val_accuracy: 0.8060
#
# Epoch 00018: val_loss improved from 0.64891 to 0.64246, saving model to ./ANN_official_He_init_sgd_momentum.h5
# Epoch 19/22
# 415/415 [==============================] - 267s 643ms/step - loss: 0.4913 - accuracy: 0.8587 - val_loss: 0.6399 - val_accuracy: 0.8046
#
# Epoch 00019: val_loss improved from 0.64246 to 0.63987, saving model to ./ANN_official_He_init_sgd_momentum.h5
# Epoch 20/22
# 415/415 [==============================] - 281s 677ms/step - loss: 0.4782 - accuracy: 0.8619 - val_loss: 0.6397 - val_accuracy: 0.8067
#
# Epoch 00020: val_loss improved from 0.63987 to 0.63970, saving model to ./ANN_official_He_init_sgd_momentum.h5
# Epoch 21/22
# 415/415 [==============================] - 258s 622ms/step - loss: 0.4758 - accuracy: 0.8627 - val_loss: 0.6390 - val_accuracy: 0.8075
#
# Epoch 00021: val_loss improved from 0.63970 to 0.63896, saving model to ./ANN_official_He_init_sgd_momentum.h5
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 22/22
# 415/415 [==============================] - 248s 597ms/step - loss: 0.4622 - accuracy: 0.8685 - val_loss: 0.6211 - val_accuracy: 0.8097
#
# Epoch 00022: val_loss improved from 0.63896 to 0.62112, saving model to ./ANN_official_He_init_sgd_momentum.h5
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_2 (Flatten)          (None, 196608)            0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1024)              201327616
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_8 (Dense)              (None, 39)                20007
# =================================================================
# Total params: 201,872,423
# Trainable params: 201,872,423
# Non-trainable params: 0
# _________________________________________________________________
# This is a model using: rmsprop
#
# model using: rmsprop
#
# Epoch 1/22
# 415/415 [==============================] - 256s 616ms/step - loss: 144.1960 - accuracy: 0.0672 - val_loss: 3.3447 - val_accuracy: 0.1197
#
# Epoch 00001: val_loss improved from inf to 3.34469, saving model to ./ANN_official_He_init_rmsprop.h5
# Epoch 2/22
# 415/415 [==============================] - 251s 604ms/step - loss: 3.6510 - accuracy: 0.0981 - val_loss: 3.2990 - val_accuracy: 0.1245
#
# Epoch 00002: val_loss improved from 3.34469 to 3.29901, saving model to ./ANN_official_He_init_rmsprop.h5
# Epoch 3/22
# 415/415 [==============================] - 250s 602ms/step - loss: 3.6081 - accuracy: 0.1063 - val_loss: 3.3060 - val_accuracy: 0.1205
#
# Epoch 00003: val_loss did not improve from 3.29901
# Epoch 4/22
# 415/415 [==============================] - 243s 585ms/step - loss: 3.4900 - accuracy: 0.1257 - val_loss: 2.9990 - val_accuracy: 0.1870
#
# Epoch 00004: val_loss improved from 3.29901 to 2.99897, saving model to ./ANN_official_He_init_rmsprop.h5
# Epoch 5/22
# 415/415 [==============================] - 250s 602ms/step - loss: 3.4019 - accuracy: 0.1455 - val_loss: 2.9133 - val_accuracy: 0.1995
#
# Epoch 00005: val_loss improved from 2.99897 to 2.91329, saving model to ./ANN_official_He_init_rmsprop.h5
# Epoch 6/22
# 415/415 [==============================] - 253s 610ms/step - loss: 3.1616 - accuracy: 0.1641 - val_loss: 2.8179 - val_accuracy: 0.2206
#
# Epoch 00006: val_loss improved from 2.91329 to 2.81788, saving model to ./ANN_official_He_init_rmsprop.h5
# Epoch 7/22
# 415/415 [==============================] - 253s 610ms/step - loss: 3.0245 - accuracy: 0.1815 - val_loss: 2.8562 - val_accuracy: 0.2507
#
# Epoch 00007: val_loss did not improve from 2.81788
# Epoch 8/22
# 415/415 [==============================] - 251s 605ms/step - loss: 2.9871 - accuracy: 0.2204 - val_loss: 2.6712 - val_accuracy: 0.2686
#
# Epoch 00008: val_loss improved from 2.81788 to 2.67125, saving model to ./ANN_official_He_init_rmsprop.h5
# Epoch 9/22
# 415/415 [==============================] - 258s 623ms/step - loss: 2.7604 - accuracy: 0.2332 - val_loss: 2.8520 - val_accuracy: 0.2179
#
# Epoch 00009: val_loss did not improve from 2.67125
# Epoch 10/22
# 415/415 [==============================] - 253s 610ms/step - loss: 2.6824 - accuracy: 0.2558 - val_loss: 2.4823 - val_accuracy: 0.2761
#
# Epoch 00010: val_loss improved from 2.67125 to 2.48225, saving model to ./ANN_official_He_init_rmsprop.h5
# Epoch 11/22
# 415/415 [==============================] - 259s 624ms/step - loss: 2.6263 - accuracy: 0.2604 - val_loss: 2.3044 - val_accuracy: 0.3519
#
# Epoch 00011: val_loss improved from 2.48225 to 2.30438, saving model to ./ANN_official_He_init_rmsprop.h5
# Epoch 12/22
# 415/415 [==============================] - 257s 620ms/step - loss: 2.5449 - accuracy: 0.2814 - val_loss: 2.4194 - val_accuracy: 0.3160
#
# Epoch 00012: val_loss did not improve from 2.30438
# Epoch 13/22
# 415/415 [==============================] - 250s 603ms/step - loss: 2.4900 - accuracy: 0.2965 - val_loss: 2.3444 - val_accuracy: 0.3400
#
# Epoch 00013: val_loss did not improve from 2.30438
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 14/22
# 415/415 [==============================] - 251s 604ms/step - loss: 2.1269 - accuracy: 0.3741 - val_loss: 1.9637 - val_accuracy: 0.4304
#
# Epoch 00014: val_loss improved from 2.30438 to 1.96375, saving model to ./ANN_official_He_init_rmsprop.h5
# Epoch 15/22
# 415/415 [==============================] - 259s 624ms/step - loss: 2.0449 - accuracy: 0.3918 - val_loss: 1.9369 - val_accuracy: 0.4393
#
# Epoch 00015: val_loss improved from 1.96375 to 1.93688, saving model to ./ANN_official_He_init_rmsprop.h5
# Epoch 16/22
# 415/415 [==============================] - 262s 632ms/step - loss: 1.9768 - accuracy: 0.4141 - val_loss: 1.8786 - val_accuracy: 0.4550
#
# Epoch 00016: val_loss improved from 1.93688 to 1.87856, saving model to ./ANN_official_He_init_rmsprop.h5
# Epoch 17/22
# 415/415 [==============================] - 261s 628ms/step - loss: 1.9246 - accuracy: 0.4279 - val_loss: 1.7940 - val_accuracy: 0.4781
#
# Epoch 00017: val_loss improved from 1.87856 to 1.79396, saving model to ./ANN_official_He_init_rmsprop.h5
# Epoch 18/22
# 415/415 [==============================] - 262s 631ms/step - loss: 1.8522 - accuracy: 0.4459 - val_loss: 1.7881 - val_accuracy: 0.4813
#
# Epoch 00018: val_loss improved from 1.79396 to 1.78813, saving model to ./ANN_official_He_init_rmsprop.h5
# Epoch 19/22
# 415/415 [==============================] - 265s 638ms/step - loss: 1.8054 - accuracy: 0.4579 - val_loss: 1.6770 - val_accuracy: 0.5112
#
# Epoch 00019: val_loss improved from 1.78813 to 1.67696, saving model to ./ANN_official_He_init_rmsprop.h5
# Epoch 20/22
# 415/415 [==============================] - 262s 630ms/step - loss: 1.7668 - accuracy: 0.4735 - val_loss: 1.6760 - val_accuracy: 0.5091
#
# Epoch 00020: val_loss improved from 1.67696 to 1.67598, saving model to ./ANN_official_He_init_rmsprop.h5
# Epoch 21/22
# 415/415 [==============================] - 254s 612ms/step - loss: 1.7144 - accuracy: 0.4849 - val_loss: 1.6970 - val_accuracy: 0.4996
#
# Epoch 00021: val_loss did not improve from 1.67598
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 22/22
# 415/415 [==============================] - 252s 608ms/step - loss: 1.6165 - accuracy: 0.5144 - val_loss: 1.5687 - val_accuracy: 0.5451
#
# Epoch 00022: val_loss improved from 1.67598 to 1.56874, saving model to ./ANN_official_He_init_rmsprop.h5
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_3 (Flatten)          (None, 196608)            0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1024)              201327616
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dense_11 (Dense)             (None, 39)                20007
# =================================================================
# Total params: 201,872,423
# Trainable params: 201,872,423
# Non-trainable params: 0
# _________________________________________________________________
# This is a model using: adam
#
# model using: adam
#
# Epoch 1/22
# 415/415 [==============================] - 263s 631ms/step - loss: 75.2290 - accuracy: 0.1758 - val_loss: 1.9588 - val_accuracy: 0.4623
#
# Epoch 00001: val_loss improved from inf to 1.95876, saving model to ./ANN_official_He_init_adam.h5
# Epoch 2/22
# 415/415 [==============================] - 261s 629ms/step - loss: 1.8812 - accuracy: 0.4564 - val_loss: 1.5526 - val_accuracy: 0.5395
#
# Epoch 00002: val_loss improved from 1.95876 to 1.55265, saving model to ./ANN_official_He_init_adam.h5
# Epoch 3/22
# 415/415 [==============================] - 257s 619ms/step - loss: 1.5938 - accuracy: 0.5246 - val_loss: 1.3146 - val_accuracy: 0.5954
#
# Epoch 00003: val_loss improved from 1.55265 to 1.31455, saving model to ./ANN_official_He_init_adam.h5
# Epoch 4/22
# 415/415 [==============================] - 255s 613ms/step - loss: 1.3808 - accuracy: 0.5815 - val_loss: 1.1849 - val_accuracy: 0.6378
#
# Epoch 00004: val_loss improved from 1.31455 to 1.18494, saving model to ./ANN_official_He_init_adam.h5
# Epoch 5/22
# 415/415 [==============================] - 256s 617ms/step - loss: 1.2392 - accuracy: 0.6242 - val_loss: 1.3893 - val_accuracy: 0.5994
#
# Epoch 00005: val_loss did not improve from 1.18494
# Epoch 6/22
# 415/415 [==============================] - 245s 591ms/step - loss: 1.2382 - accuracy: 0.6236 - val_loss: 1.2131 - val_accuracy: 0.6351
#
# Epoch 00006: val_loss did not improve from 1.18494
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 7/22
# 415/415 [==============================] - 248s 597ms/step - loss: 0.8807 - accuracy: 0.7262 - val_loss: 0.8642 - val_accuracy: 0.7382
#
# Epoch 00007: val_loss improved from 1.18494 to 0.86418, saving model to ./ANN_official_He_init_adam.h5
# Epoch 8/22
# 415/415 [==============================] - 261s 628ms/step - loss: 0.7937 - accuracy: 0.7507 - val_loss: 0.8436 - val_accuracy: 0.7371
#
# Epoch 00008: val_loss improved from 0.86418 to 0.84358, saving model to ./ANN_official_He_init_adam.h5
# Epoch 9/22
# 415/415 [==============================] - 259s 625ms/step - loss: 0.7861 - accuracy: 0.7562 - val_loss: 0.8232 - val_accuracy: 0.7463
#
# Epoch 00009: val_loss improved from 0.84358 to 0.82320, saving model to ./ANN_official_He_init_adam.h5
# Epoch 10/22
# 415/415 [==============================] - 259s 625ms/step - loss: 0.7644 - accuracy: 0.7577 - val_loss: 0.7888 - val_accuracy: 0.7591
#
# Epoch 00010: val_loss improved from 0.82320 to 0.78881, saving model to ./ANN_official_He_init_adam.h5
# Epoch 11/22
# 415/415 [==============================] - 261s 629ms/step - loss: 0.7420 - accuracy: 0.7661 - val_loss: 0.8490 - val_accuracy: 0.7388
#
# Epoch 00011: val_loss did not improve from 0.78881
# Epoch 12/22
# 415/415 [==============================] - 293s 707ms/step - loss: 0.7397 - accuracy: 0.7648 - val_loss: 0.8387 - val_accuracy: 0.7435
#
# Epoch 00012: val_loss did not improve from 0.78881
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 13/22
# 415/415 [==============================] - 301s 725ms/step - loss: 0.6429 - accuracy: 0.7998 - val_loss: 0.7294 - val_accuracy: 0.7760
#
# Epoch 00013: val_loss improved from 0.78881 to 0.72940, saving model to ./ANN_official_He_init_adam.h5
# Epoch 14/22
# 415/415 [==============================] - 311s 749ms/step - loss: 0.6249 - accuracy: 0.8059 - val_loss: 0.7224 - val_accuracy: 0.7794
#
# Epoch 00014: val_loss improved from 0.72940 to 0.72245, saving model to ./ANN_official_He_init_adam.h5
# Epoch 15/22
# 415/415 [==============================] - 314s 756ms/step - loss: 0.6233 - accuracy: 0.8061 - val_loss: 0.7178 - val_accuracy: 0.7774
#
# Epoch 00015: val_loss improved from 0.72245 to 0.71783, saving model to ./ANN_official_He_init_adam.h5
# Epoch 16/22
# 415/415 [==============================] - 315s 759ms/step - loss: 0.6177 - accuracy: 0.8102 - val_loss: 0.7406 - val_accuracy: 0.7740
#
# Epoch 00016: val_loss did not improve from 0.71783
# Epoch 17/22
# 415/415 [==============================] - 299s 720ms/step - loss: 0.5998 - accuracy: 0.8151 - val_loss: 0.7333 - val_accuracy: 0.7743
#
# Epoch 00017: val_loss did not improve from 0.71783
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 18/22
# 415/415 [==============================] - 297s 715ms/step - loss: 0.5873 - accuracy: 0.8201 - val_loss: 0.7087 - val_accuracy: 0.7822
#
# Epoch 00018: val_loss improved from 0.71783 to 0.70874, saving model to ./ANN_official_He_init_adam.h5
# Epoch 19/22
# 415/415 [==============================] - 311s 749ms/step - loss: 0.5885 - accuracy: 0.8183 - val_loss: 0.7100 - val_accuracy: 0.7832
#
# Epoch 00019: val_loss did not improve from 0.70874
# Epoch 20/22
# 415/415 [==============================] - 304s 732ms/step - loss: 0.5784 - accuracy: 0.8216 - val_loss: 0.7094 - val_accuracy: 0.7833
#
# Epoch 00020: val_loss did not improve from 0.70874
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# Epoch 21/22
# 415/415 [==============================] - 304s 732ms/step - loss: 0.5848 - accuracy: 0.8213 - val_loss: 0.7041 - val_accuracy: 0.7852
#
# Epoch 00021: val_loss improved from 0.70874 to 0.70415, saving model to ./ANN_official_He_init_adam.h5
# Epoch 22/22
# 415/415 [==============================] - 317s 763ms/step - loss: 0.5753 - accuracy: 0.8219 - val_loss: 0.7042 - val_accuracy: 0.7847
#
# Epoch 00022: val_loss did not improve from 0.70415

# %%
#Drawing
plt.subplot(4, 1, 1)
plt.title('Training loss')
plt.xlabel('Epoch')

plt.subplot(4, 1, 2)
plt.title('Validation loss')
plt.xlabel('Epoch')

plt.subplot(4, 1, 3)
plt.title('Training accuracy')
plt.xlabel('Epoch')

plt.subplot(4, 1, 4)
plt.title('Validation accuracy')
plt.xlabel('Epoch')

for update_rule, milestone in history.items():
    plt.subplot(4, 1, 1)
    plt.plot(milestone.history['loss'], 'o', label=update_rule)

    plt.subplot(4, 1, 2)
    plt.plot(milestone.history['val_loss'], 'o', label=update_rule)

    plt.subplot(4, 1, 3)
    plt.plot(milestone.history['accuracy'], '-o', label=update_rule)
    
    plt.subplot(4, 1, 4)
    plt.plot(milestone.history['val_accuracy'], '-o', label=update_rule)

for i in [1, 2, 3, 4]:
    plt.subplot(4, 1, i)
    plt.legend(loc='upper center', ncol=4)
plt.gcf().set_size_inches(20, 20)
plt.show()
