# %%
from tensorflow.keras.layers import Input, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from glob import glob
import keras
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import tensorflow as tf

# %%
size = 256
batch_size = 128
epochs = 7
history = {}
def build_model(initializer, lr):
    input_shape = (size, size, 3)
    hidden_layer_1 = 1024
    hidden_layer_2 = 512
    num_classes = 39
    layers = [
        Flatten(input_shape=input_shape),
        Dense(hidden_layer_1, activation='relu', kernel_initializer=initializer),
        Dense(hidden_layer_2, activation='relu', kernel_initializer=initializer),
        Dense(num_classes, activation='softmax', kernel_initializer=initializer)
    ]
    model = tf.keras.Sequential(layers)
    model.compile(
    loss='categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(learning_rate=lr, momentum=0.9, nesterov=False),
    metrics=['accuracy']
    )
    return model

# %%
#optim = {}
#sgd = tf.keras.optimizers.SGD(learning_rate=0.01)
#optim['sgd'] = sgd
#sgd_momentum = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9, nesterov=False)
#optim['sgd_momentum'] = sgd_momentum
#rmsprop = tf.keras.optimizers.RMSprop(
    #learning_rate=0.01, rho=0.9, momentum=0.0, epsilon=1e-07)
#optim['rmsprop'] = rmsprop
#adam = tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07)
#optim['adam'] = adam
lr = [1., 0.1, 0.01, 1e-3, 1e-4]
initializer = tf.keras.initializers.GlorotNormal()

# %%
train_path = '../input/official-leaf/train_aug'
test_path = '../input/official-test/test'
gen = ImageDataGenerator(rescale=1./255)
train_generator = gen.flow_from_directory(train_path,     
    target_size = (size, size),
    shuffle=True, 
    batch_size=batch_size
)
valid_generator = gen.flow_from_directory(test_path,     
    target_size = (size, size),
    shuffle=False, 
    batch_size=batch_size
)
# Out:
# Found 53164 images belonging to 39 classes.
# Found 11104 images belonging to 39 classes.

# %%
def train_model(lr):
    model = build_model(initializer, lr)
    model.summary()
    print('This is a SGD_momentum model using lr of:', lr)
    print()
    model_save = ModelCheckpoint('./ANN_official_lr_' + str(lr) + '.h5',
                                 save_best_only = True, 
                                 save_weights_only = False,
                                 monitor = 'val_loss', 
                                 mode = 'min', verbose = 1)

    milestones = model.fit(train_generator,
              validation_data=valid_generator,
              epochs=epochs,
              steps_per_epoch=train_generator.n//train_generator.batch_size,
              validation_steps = valid_generator.n//valid_generator.batch_size,
              callbacks = [model_save, reduce_lr]
              )
    history[str(lr)] = milestones

# %%
#early_stop = EarlyStopping(monitor = 'val_loss', min_delta = 0.001, 
                               #patience = 5, mode = 'min', verbose = 1,
                               #restore_best_weights = True)
reduce_lr = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.2, 
                                      patience = 2, min_delta = 0.001, 
                                      mode = 'min', verbose = 1)
for learning_rate in lr :
    train_model(learning_rate)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 196608)            0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              201327616
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_2 (Dense)              (None, 39)                20007
# =================================================================
# Total params: 201,872,423
# Trainable params: 201,872,423
# Non-trainable params: 0
# _________________________________________________________________
# This is a SGD_momentum model using lr of: 1.0
#
# Epoch 1/7
# 415/415 [==============================] - 640s 2s/step - loss: nan - accuracy: 0.0244 - val_loss: nan - val_accuracy: 0.0114
#
# Epoch 00001: val_loss did not improve from inf
# Epoch 2/7
# 415/415 [==============================] - 278s 671ms/step - loss: nan - accuracy: 0.0187 - val_loss: nan - val_accuracy: 0.0114
#
# Epoch 00002: val_loss did not improve from inf
#
# Epoch 00002: ReduceLROnPlateau reducing learning rate to 0.2.
# Epoch 3/7
# 415/415 [==============================] - 278s 669ms/step - loss: nan - accuracy: 0.0190 - val_loss: nan - val_accuracy: 0.0114
#
# Epoch 00003: val_loss did not improve from inf
# Epoch 4/7
# 415/415 [==============================] - 291s 700ms/step - loss: nan - accuracy: 0.0190 - val_loss: nan - val_accuracy: 0.0114
#
# Epoch 00004: val_loss did not improve from inf
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.04000000059604645.
# Epoch 5/7
# 415/415 [==============================] - 303s 730ms/step - loss: nan - accuracy: 0.0194 - val_loss: nan - val_accuracy: 0.0114
#
# Epoch 00005: val_loss did not improve from inf
# Epoch 6/7
# 415/415 [==============================] - 282s 679ms/step - loss: nan - accuracy: 0.0189 - val_loss: nan - val_accuracy: 0.0114
#
# Epoch 00006: val_loss did not improve from inf
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.007999999821186066.
# Epoch 7/7
# 415/415 [==============================] - 282s 680ms/step - loss: nan - accuracy: 0.0178 - val_loss: nan - val_accuracy: 0.0114
#
# Epoch 00007: val_loss did not improve from inf
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 196608)            0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              201327616
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_5 (Dense)              (None, 39)                20007
# =================================================================
# Total params: 201,872,423
# Trainable params: 201,872,423
# Non-trainable params: 0
# _________________________________________________________________
# This is a SGD_momentum model using lr of: 0.1
#
# Epoch 1/7
# 415/415 [==============================] - 280s 674ms/step - loss: nan - accuracy: 0.0287 - val_loss: nan - val_accuracy: 0.0114
#
# Epoch 00001: val_loss did not improve from inf
# Epoch 2/7
# 415/415 [==============================] - 291s 702ms/step - loss: nan - accuracy: 0.0189 - val_loss: nan - val_accuracy: 0.0114
#
# Epoch 00002: val_loss did not improve from inf
#
# Epoch 00002: ReduceLROnPlateau reducing learning rate to 0.020000000298023225.
# Epoch 3/7
# 415/415 [==============================] - 291s 699ms/step - loss: nan - accuracy: 0.0193 - val_loss: nan - val_accuracy: 0.0114
#
# Epoch 00003: val_loss did not improve from inf
# Epoch 4/7
# 415/415 [==============================] - 279s 672ms/step - loss: nan - accuracy: 0.0191 - val_loss: nan - val_accuracy: 0.0114
#
# Epoch 00004: val_loss did not improve from inf
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.003999999910593033.
# Epoch 5/7
# 415/415 [==============================] - 295s 710ms/step - loss: nan - accuracy: 0.0198 - val_loss: nan - val_accuracy: 0.0114
#
# Epoch 00005: val_loss did not improve from inf
# Epoch 6/7
# 415/415 [==============================] - 282s 679ms/step - loss: nan - accuracy: 0.0186 - val_loss: nan - val_accuracy: 0.0114
#
# Epoch 00006: val_loss did not improve from inf
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0007999999448657036.
# Epoch 7/7
# 415/415 [==============================] - 292s 704ms/step - loss: nan - accuracy: 0.0190 - val_loss: nan - val_accuracy: 0.0114
#
# Epoch 00007: val_loss did not improve from inf
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_2 (Flatten)          (None, 196608)            0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1024)              201327616
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_8 (Dense)              (None, 39)                20007
# =================================================================
# Total params: 201,872,423
# Trainable params: 201,872,423
# Non-trainable params: 0
# _________________________________________________________________
# This is a SGD_momentum model using lr of: 0.01
#
# Epoch 1/7
# 415/415 [==============================] - 280s 673ms/step - loss: 8.6432 - accuracy: 0.0721 - val_loss: 3.4441 - val_accuracy: 0.0862
#
# Epoch 00001: val_loss improved from inf to 3.44407, saving model to ./ANN_official_lr_0.01.h5
# Epoch 2/7
# 415/415 [==============================] - 273s 659ms/step - loss: 3.5457 - accuracy: 0.0822 - val_loss: 3.4320 - val_accuracy: 0.1001
#
# Epoch 00002: val_loss improved from 3.44407 to 3.43198, saving model to ./ANN_official_lr_0.01.h5
# Epoch 3/7
# 415/415 [==============================] - 249s 601ms/step - loss: 3.5262 - accuracy: 0.0809 - val_loss: 3.4357 - val_accuracy: 0.1001
#
# Epoch 00003: val_loss did not improve from 3.43198
# Epoch 4/7
# 415/415 [==============================] - 233s 562ms/step - loss: 3.5317 - accuracy: 0.0814 - val_loss: 3.4319 - val_accuracy: 0.1001
#
# Epoch 00004: val_loss improved from 3.43198 to 3.43185, saving model to ./ANN_official_lr_0.01.h5
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# Epoch 5/7
# 415/415 [==============================] - 233s 562ms/step - loss: 3.5289 - accuracy: 0.0823 - val_loss: 3.4331 - val_accuracy: 0.1001
#
# Epoch 00005: val_loss did not improve from 3.43185
# Epoch 6/7
# 415/415 [==============================] - 233s 560ms/step - loss: 3.5241 - accuracy: 0.0821 - val_loss: 3.4338 - val_accuracy: 0.1001
#
# Epoch 00006: val_loss did not improve from 3.43185
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0003999999724328518.
# Epoch 7/7
# 415/415 [==============================] - 237s 571ms/step - loss: 3.5234 - accuracy: 0.0850 - val_loss: 3.4339 - val_accuracy: 0.1001
#
# Epoch 00007: val_loss did not improve from 3.43185
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_3 (Flatten)          (None, 196608)            0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1024)              201327616
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dense_11 (Dense)             (None, 39)                20007
# =================================================================
# Total params: 201,872,423
# Trainable params: 201,872,423
# Non-trainable params: 0
# _________________________________________________________________
# This is a SGD_momentum model using lr of: 0.001
#
# Epoch 1/7
# 415/415 [==============================] - 234s 562ms/step - loss: 2.7389 - accuracy: 0.2843 - val_loss: 1.6910 - val_accuracy: 0.5270
#
# Epoch 00001: val_loss improved from inf to 1.69095, saving model to ./ANN_official_lr_0.001.h5
# Epoch 2/7
# 415/415 [==============================] - 236s 569ms/step - loss: 1.6653 - accuracy: 0.5212 - val_loss: 1.4498 - val_accuracy: 0.5698
#
# Epoch 00002: val_loss improved from 1.69095 to 1.44975, saving model to ./ANN_official_lr_0.001.h5
# Epoch 3/7
# 415/415 [==============================] - 281s 676ms/step - loss: 1.3933 - accuracy: 0.5909 - val_loss: 1.4155 - val_accuracy: 0.5873
#
# Epoch 00003: val_loss improved from 1.44975 to 1.41553, saving model to ./ANN_official_lr_0.001.h5
# Epoch 4/7
# 415/415 [==============================] - 237s 572ms/step - loss: 1.2516 - accuracy: 0.6279 - val_loss: 1.0968 - val_accuracy: 0.6705
#
# Epoch 00004: val_loss improved from 1.41553 to 1.09680, saving model to ./ANN_official_lr_0.001.h5
# Epoch 5/7
# 415/415 [==============================] - 241s 581ms/step - loss: 1.1168 - accuracy: 0.6647 - val_loss: 0.9899 - val_accuracy: 0.7075
#
# Epoch 00005: val_loss improved from 1.09680 to 0.98986, saving model to ./ANN_official_lr_0.001.h5
# Epoch 6/7
# 415/415 [==============================] - 263s 634ms/step - loss: 1.0003 - accuracy: 0.6991 - val_loss: 0.9450 - val_accuracy: 0.7175
#
# Epoch 00006: val_loss improved from 0.98986 to 0.94497, saving model to ./ANN_official_lr_0.001.h5
# Epoch 7/7
# 415/415 [==============================] - 315s 761ms/step - loss: 0.9420 - accuracy: 0.7131 - val_loss: 0.9757 - val_accuracy: 0.7079
#
# Epoch 00007: val_loss did not improve from 0.94497
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_4 (Flatten)          (None, 196608)            0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1024)              201327616
# _________________________________________________________________
# dense_13 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dense_14 (Dense)             (None, 39)                20007
# =================================================================
# Total params: 201,872,423
# Trainable params: 201,872,423
# Non-trainable params: 0
# _________________________________________________________________
# This is a SGD_momentum model using lr of: 0.0001
#
# Epoch 1/7
# 415/415 [==============================] - 291s 701ms/step - loss: 3.0720 - accuracy: 0.2201 - val_loss: 2.1534 - val_accuracy: 0.4287
#
# Epoch 00001: val_loss improved from inf to 2.15338, saving model to ./ANN_official_lr_0.0001.h5
# Epoch 2/7
# 415/415 [==============================] - 294s 708ms/step - loss: 2.1703 - accuracy: 0.4253 - val_loss: 1.7920 - val_accuracy: 0.5271
#
# Epoch 00002: val_loss improved from 2.15338 to 1.79202, saving model to ./ANN_official_lr_0.0001.h5
# Epoch 3/7
# 415/415 [==============================] - 313s 754ms/step - loss: 1.8904 - accuracy: 0.4914 - val_loss: 1.6733 - val_accuracy: 0.5439
#
# Epoch 00003: val_loss improved from 1.79202 to 1.67327, saving model to ./ANN_official_lr_0.0001.h5
# Epoch 4/7
# 415/415 [==============================] - 321s 773ms/step - loss: 1.7103 - accuracy: 0.5343 - val_loss: 1.5127 - val_accuracy: 0.5826
#
# Epoch 00004: val_loss improved from 1.67327 to 1.51272, saving model to ./ANN_official_lr_0.0001.h5
# Epoch 5/7
# 415/415 [==============================] - 307s 740ms/step - loss: 1.5953 - accuracy: 0.5634 - val_loss: 1.4501 - val_accuracy: 0.6159
#
# Epoch 00005: val_loss improved from 1.51272 to 1.45005, saving model to ./ANN_official_lr_0.0001.h5
# Epoch 6/7
# 415/415 [==============================] - 301s 726ms/step - loss: 1.5059 - accuracy: 0.5847 - val_loss: 1.3833 - val_accuracy: 0.6193
#
# Epoch 00006: val_loss improved from 1.45005 to 1.38326, saving model to ./ANN_official_lr_0.0001.h5
# Epoch 7/7
# 415/415 [==============================] - 293s 705ms/step - loss: 1.4332 - accuracy: 0.6007 - val_loss: 1.3653 - val_accuracy: 0.6229
#
# Epoch 00007: val_loss improved from 1.38326 to 1.36528, saving model to ./ANN_official_lr_0.0001.h5

# %%
#Drawing
plt.subplot(4, 1, 1)
plt.title('Training loss')
plt.xlabel('Iteration')

plt.subplot(4, 1, 2)
plt.title('Validation loss')
plt.xlabel('Iteration')

plt.subplot(4, 1, 3)
plt.title('Training accuracy')
plt.xlabel('Epoch')

plt.subplot(4, 1, 4)
plt.title('Validation accuracy')
plt.xlabel('Epoch')

for update_rule, milestone in history.items():
    plt.subplot(4, 1, 1)
    plt.plot(milestone.history['loss'], 'o', label=update_rule)

    plt.subplot(4, 1, 2)
    plt.plot(milestone.history['val_loss'], 'o', label=update_rule)

    plt.subplot(4, 1, 3)
    plt.plot(milestone.history['accuracy'], '-o', label=update_rule)
    
    plt.subplot(4, 1, 4)
    plt.plot(milestone.history['val_accuracy'], '-o', label=update_rule)

for i in [1, 2, 3, 4]:
    plt.subplot(4, 1, i)
    plt.legend(loc='upper center', ncol=4)
plt.gcf().set_size_inches(20, 20)
plt.show()
