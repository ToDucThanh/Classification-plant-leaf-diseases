# %%
from tensorflow.keras.layers import Dense, Flatten, BatchNormalization, Activation
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# %%
size = 256
batch_size = 128
epochs = 20
history = {}
def build_model(initializer, optimizer):
    input_shape = (size, size, 3)
    hidden_layer_1 = 1024
    hidden_layer_2 = 512
    num_classes = 39
    layers = [
        Flatten(input_shape=input_shape),
        BatchNormalization(),
        Dense(hidden_layer_1, kernel_initializer=initializer),
        BatchNormalization(),
        Activation('relu'),
        Dense(hidden_layer_2, kernel_initializer=initializer),
        BatchNormalization(),
        Activation('relu'),
        Dense(num_classes, activation='softmax', kernel_initializer=initializer)
    ]
    model = tf.keras.Sequential(layers)
    model.compile(
    loss='categorical_crossentropy',
    optimizer=optimizer,
    metrics=['accuracy']
    )
    return model

# %%
optim = {}
sgd_momentum = tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9, nesterov=False)
optim['sgd_momentum'] = sgd_momentum
adam = tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07)
optim['adam'] = adam
initializer = tf.keras.initializers.HeNormal()

# %%
train_path = '../input/traindata/train_aug'
test_path = '../input/testdata/test'
train_gen = ImageDataGenerator(rescale=1./255, vertical_flip=True, brightness_range=(0.2, 0.8))
test_gen = ImageDataGenerator(rescale=1./255)
train_generator = train_gen.flow_from_directory(train_path,     
    target_size = (size, size),
    shuffle=True, 
    batch_size=batch_size
)
valid_generator = test_gen.flow_from_directory(test_path,     
    target_size = (size, size),
    shuffle=False, 
    batch_size=batch_size
)
# Out:
# Found 53164 images belonging to 39 classes.
# Found 11104 images belonging to 39 classes.

# %%
def train_model(k, v):
    model = build_model(initializer, v)
    model.summary()
    print('This is a model using:', k)
    model_save = ModelCheckpoint('./ANN_BN_before_activation_' + k + '.h5',
                                 save_best_only = True, 
                                 save_weights_only = False,
                                 monitor = 'val_loss', 
                                 mode = 'min', verbose = 1)
    milestone = model.fit(train_generator,
              validation_data=valid_generator,
              epochs=epochs,
              steps_per_epoch=train_generator.n//train_generator.batch_size - 1,
              validation_steps = valid_generator.n//valid_generator.batch_size,
              callbacks = [model_save, early_stop, reduce_lr]
              )
    history[k] = milestone

# %%
early_stop = EarlyStopping(monitor = 'val_loss', min_delta = 0.001, 
                               patience = 5, mode = 'min', verbose = 1,
                               restore_best_weights = True)
reduce_lr = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.2, 
                                      patience = 2, min_delta = 0.001, 
                                      mode = 'min', verbose = 1)

for k, v in optim.items():
    train_model(k, v)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 196608)            0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 196608)            786432
# _________________________________________________________________
# dense (Dense)                (None, 1024)              201327616
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 1024)              4096
# _________________________________________________________________
# activation (Activation)      (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 39)                20007
# =================================================================
# Total params: 202,664,999
# Trainable params: 202,268,711
# Non-trainable params: 396,288
# _________________________________________________________________
# This is a model using: sgd_momentum
# Epoch 1/20
# 414/414 [==============================] - 653s 2s/step - loss: 2.4487 - accuracy: 0.3642 - val_loss: 1.8095 - val_accuracy: 0.4847
#
# Epoch 00001: val_loss improved from inf to 1.80955, saving model to ./ANN_BN_before_activation_sgd_momentum.h5
# Epoch 2/20
# 414/414 [==============================] - 286s 690ms/step - loss: 1.5767 - accuracy: 0.5698 - val_loss: 1.3224 - val_accuracy: 0.6167
#
# Epoch 00002: val_loss improved from 1.80955 to 1.32241, saving model to ./ANN_BN_before_activation_sgd_momentum.h5
# Epoch 3/20
# 414/414 [==============================] - 285s 689ms/step - loss: 1.3015 - accuracy: 0.6463 - val_loss: 1.1391 - val_accuracy: 0.6678
#
# Epoch 00003: val_loss improved from 1.32241 to 1.13909, saving model to ./ANN_BN_before_activation_sgd_momentum.h5
# Epoch 4/20
# 414/414 [==============================] - 292s 705ms/step - loss: 1.1551 - accuracy: 0.6827 - val_loss: 1.1615 - val_accuracy: 0.6529
#
# Epoch 00004: val_loss did not improve from 1.13909
# Epoch 5/20
# 414/414 [==============================] - 298s 718ms/step - loss: 1.0412 - accuracy: 0.7141 - val_loss: 1.0323 - val_accuracy: 0.6904
#
# Epoch 00005: val_loss improved from 1.13909 to 1.03226, saving model to ./ANN_BN_before_activation_sgd_momentum.h5
# Epoch 6/20
# 414/414 [==============================] - 296s 714ms/step - loss: 0.9376 - accuracy: 0.7422 - val_loss: 1.0593 - val_accuracy: 0.6825
#
# Epoch 00006: val_loss did not improve from 1.03226
# Epoch 7/20
# 414/414 [==============================] - 289s 698ms/step - loss: 0.8822 - accuracy: 0.7570 - val_loss: 1.0013 - val_accuracy: 0.7034
#
# Epoch 00007: val_loss improved from 1.03226 to 1.00132, saving model to ./ANN_BN_before_activation_sgd_momentum.h5
# Epoch 8/20
# 414/414 [==============================] - 301s 727ms/step - loss: 0.8228 - accuracy: 0.7717 - val_loss: 0.9016 - val_accuracy: 0.7312
#
# Epoch 00008: val_loss improved from 1.00132 to 0.90161, saving model to ./ANN_BN_before_activation_sgd_momentum.h5
# Epoch 9/20
# 414/414 [==============================] - 308s 743ms/step - loss: 0.7616 - accuracy: 0.7931 - val_loss: 0.9305 - val_accuracy: 0.7194
#
# Epoch 00009: val_loss did not improve from 0.90161
# Epoch 10/20
# 414/414 [==============================] - 293s 708ms/step - loss: 0.7231 - accuracy: 0.8006 - val_loss: 0.8188 - val_accuracy: 0.7528
#
# Epoch 00010: val_loss improved from 0.90161 to 0.81877, saving model to ./ANN_BN_before_activation_sgd_momentum.h5
# Epoch 11/20
# 414/414 [==============================] - 297s 716ms/step - loss: 0.6713 - accuracy: 0.8163 - val_loss: 0.8286 - val_accuracy: 0.7509
#
# Epoch 00011: val_loss did not improve from 0.81877
# Epoch 12/20
# 414/414 [==============================] - 295s 712ms/step - loss: 0.6277 - accuracy: 0.8315 - val_loss: 0.8032 - val_accuracy: 0.7590
#
# Epoch 00012: val_loss improved from 0.81877 to 0.80318, saving model to ./ANN_BN_before_activation_sgd_momentum.h5
# Epoch 13/20
# 414/414 [==============================] - 301s 727ms/step - loss: 0.5965 - accuracy: 0.8375 - val_loss: 0.8942 - val_accuracy: 0.7391
#
# Epoch 00013: val_loss did not improve from 0.80318
# Epoch 14/20
# 414/414 [==============================] - 297s 717ms/step - loss: 0.5754 - accuracy: 0.8436 - val_loss: 0.7765 - val_accuracy: 0.7669
#
# Epoch 00014: val_loss improved from 0.80318 to 0.77650, saving model to ./ANN_BN_before_activation_sgd_momentum.h5
# Epoch 15/20
# 414/414 [==============================] - 303s 732ms/step - loss: 0.5377 - accuracy: 0.8551 - val_loss: 0.7886 - val_accuracy: 0.7634
#
# Epoch 00015: val_loss did not improve from 0.77650
# Epoch 16/20
# 414/414 [==============================] - 296s 716ms/step - loss: 0.5042 - accuracy: 0.8687 - val_loss: 0.9801 - val_accuracy: 0.7253
#
# Epoch 00016: val_loss did not improve from 0.77650
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 17/20
# 414/414 [==============================] - 298s 719ms/step - loss: 0.4182 - accuracy: 0.8919 - val_loss: 0.6599 - val_accuracy: 0.8026
#
# Epoch 00017: val_loss improved from 0.77650 to 0.65985, saving model to ./ANN_BN_before_activation_sgd_momentum.h5
# Epoch 18/20
# 414/414 [==============================] - 304s 734ms/step - loss: 0.3541 - accuracy: 0.9158 - val_loss: 0.6553 - val_accuracy: 0.8025
#
# Epoch 00018: val_loss improved from 0.65985 to 0.65530, saving model to ./ANN_BN_before_activation_sgd_momentum.h5
# Epoch 19/20
# 414/414 [==============================] - 307s 741ms/step - loss: 0.3445 - accuracy: 0.9198 - val_loss: 0.6511 - val_accuracy: 0.8070
#
# Epoch 00019: val_loss improved from 0.65530 to 0.65106, saving model to ./ANN_BN_before_activation_sgd_momentum.h5
# Epoch 20/20
# 414/414 [==============================] - 300s 725ms/step - loss: 0.3331 - accuracy: 0.9240 - val_loss: 0.6641 - val_accuracy: 0.8021
#
# Epoch 00020: val_loss did not improve from 0.65106
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 196608)            0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 196608)            786432
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              201327616
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 1024)              4096
# _________________________________________________________________
# activation_2 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               524800
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_3 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 39)                20007
# =================================================================
# Total params: 202,664,999
# Trainable params: 202,268,711
# Non-trainable params: 396,288
# _________________________________________________________________
# This is a model using: adam
# Epoch 1/20
# 414/414 [==============================] - 304s 730ms/step - loss: 2.3838 - accuracy: 0.3572 - val_loss: 1.8642 - val_accuracy: 0.4660
#
# Epoch 00001: val_loss improved from inf to 1.86415, saving model to ./ANN_BN_before_activation_adam.h5
# Epoch 2/20
# 414/414 [==============================] - 307s 742ms/step - loss: 1.3778 - accuracy: 0.5894 - val_loss: 1.6705 - val_accuracy: 0.5348
#
# Epoch 00002: val_loss improved from 1.86415 to 1.67049, saving model to ./ANN_BN_before_activation_adam.h5
# Epoch 3/20
# 414/414 [==============================] - 323s 780ms/step - loss: 1.1274 - accuracy: 0.6585 - val_loss: 1.5346 - val_accuracy: 0.5906
#
# Epoch 00003: val_loss improved from 1.67049 to 1.53461, saving model to ./ANN_BN_before_activation_adam.h5
# Epoch 4/20
# 414/414 [==============================] - 305s 737ms/step - loss: 1.0030 - accuracy: 0.6921 - val_loss: 1.1333 - val_accuracy: 0.6764
#
# Epoch 00004: val_loss improved from 1.53461 to 1.13335, saving model to ./ANN_BN_before_activation_adam.h5
# Epoch 5/20
# 414/414 [==============================] - 303s 731ms/step - loss: 0.8640 - accuracy: 0.7357 - val_loss: 1.2397 - val_accuracy: 0.6470
#
# Epoch 00005: val_loss did not improve from 1.13335
# Epoch 6/20
# 414/414 [==============================] - 293s 708ms/step - loss: 0.7941 - accuracy: 0.7526 - val_loss: 1.2855 - val_accuracy: 0.6459
#
# Epoch 00006: val_loss did not improve from 1.13335
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 7/20
# 414/414 [==============================] - 293s 706ms/step - loss: 0.6003 - accuracy: 0.8147 - val_loss: 0.6834 - val_accuracy: 0.7900
#
# Epoch 00007: val_loss improved from 1.13335 to 0.68338, saving model to ./ANN_BN_before_activation_adam.h5
# Epoch 8/20
# 414/414 [==============================] - 302s 730ms/step - loss: 0.5217 - accuracy: 0.8424 - val_loss: 0.5960 - val_accuracy: 0.8137
#
# Epoch 00008: val_loss improved from 0.68338 to 0.59604, saving model to ./ANN_BN_before_activation_adam.h5
# Epoch 9/20
# 414/414 [==============================] - 307s 743ms/step - loss: 0.4871 - accuracy: 0.8507 - val_loss: 0.6392 - val_accuracy: 0.8070
#
# Epoch 00009: val_loss did not improve from 0.59604
# Epoch 10/20
# 414/414 [==============================] - 294s 710ms/step - loss: 0.4701 - accuracy: 0.8560 - val_loss: 0.6851 - val_accuracy: 0.7944
#
# Epoch 00010: val_loss did not improve from 0.59604
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 11/20
# 414/414 [==============================] - 296s 714ms/step - loss: 0.4123 - accuracy: 0.8750 - val_loss: 0.5604 - val_accuracy: 0.8328
#
# Epoch 00011: val_loss improved from 0.59604 to 0.56038, saving model to ./ANN_BN_before_activation_adam.h5
# Epoch 12/20
# 414/414 [==============================] - 302s 729ms/step - loss: 0.3889 - accuracy: 0.8846 - val_loss: 0.5564 - val_accuracy: 0.8329
#
# Epoch 00012: val_loss improved from 0.56038 to 0.55637, saving model to ./ANN_BN_before_activation_adam.h5
# Epoch 13/20
# 414/414 [==============================] - 307s 742ms/step - loss: 0.3705 - accuracy: 0.8930 - val_loss: 0.5490 - val_accuracy: 0.8347
#
# Epoch 00013: val_loss improved from 0.55637 to 0.54900, saving model to ./ANN_BN_before_activation_adam.h5
# Epoch 14/20
# 414/414 [==============================] - 311s 751ms/step - loss: 0.3633 - accuracy: 0.8921 - val_loss: 0.5648 - val_accuracy: 0.8298
#
# Epoch 00014: val_loss did not improve from 0.54900
# Epoch 15/20
# 414/414 [==============================] - 292s 707ms/step - loss: 0.3609 - accuracy: 0.8935 - val_loss: 0.5450 - val_accuracy: 0.8364
#
# Epoch 00015: val_loss improved from 0.54900 to 0.54498, saving model to ./ANN_BN_before_activation_adam.h5
# Epoch 16/20
# 414/414 [==============================] - 303s 733ms/step - loss: 0.3539 - accuracy: 0.8963 - val_loss: 0.5635 - val_accuracy: 0.8320
#
# Epoch 00016: val_loss did not improve from 0.54498
# Epoch 17/20
# 414/414 [==============================] - 296s 714ms/step - loss: 0.3520 - accuracy: 0.8966 - val_loss: 0.5438 - val_accuracy: 0.8386
#
# Epoch 00017: val_loss improved from 0.54498 to 0.54382, saving model to ./ANN_BN_before_activation_adam.h5
# Epoch 18/20
# 414/414 [==============================] - 303s 732ms/step - loss: 0.3312 - accuracy: 0.9019 - val_loss: 0.5561 - val_accuracy: 0.8364
#
# Epoch 00018: val_loss did not improve from 0.54382
# Epoch 19/20
# 414/414 [==============================] - 298s 718ms/step - loss: 0.3291 - accuracy: 0.9042 - val_loss: 0.5557 - val_accuracy: 0.8342
#
# Epoch 00019: val_loss did not improve from 0.54382
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 20/20
# 414/414 [==============================] - 295s 713ms/step - loss: 0.3095 - accuracy: 0.9091 - val_loss: 0.5342 - val_accuracy: 0.8447
#
# Epoch 00020: val_loss improved from 0.54382 to 0.53416, saving model to ./ANN_BN_before_activation_adam.h5

# %%
#Drawing
plt.subplot(4, 1, 1)
plt.title('Training loss')
plt.xlabel('Epoch')

plt.subplot(4, 1, 2)
plt.title('Validation loss')
plt.xlabel('Epoch')

plt.subplot(4, 1, 3)
plt.title('Training accuracy')
plt.xlabel('Epoch')

plt.subplot(4, 1, 4)
plt.title('Validation accuracy')
plt.xlabel('Epoch')

for update_rule, milestone in history.items():
    plt.subplot(4, 1, 1)
    plt.plot(milestone.history['loss'], 'o', label=update_rule)

    plt.subplot(4, 1, 2)
    plt.plot(milestone.history['val_loss'], 'o', label=update_rule)
    plt.subplot(4, 1, 3)
    plt.plot(milestone.history['accuracy'], '-o', label=update_rule)
    
    plt.subplot(4, 1, 4)
    plt.plot(milestone.history['val_accuracy'], '-o', label=update_rule)

for i in [1, 2, 3, 4]:
    plt.subplot(4, 1, i)
    plt.legend(loc='upper center', ncol=4)
plt.gcf().set_size_inches(20, 20)
plt.show()
