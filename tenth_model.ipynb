# %%
from tensorflow.keras.layers import Dense, Flatten, BatchNormalization, LayerNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# %%
size = 256
batch_size = 128
epochs = 40
history = {}
def build_model(initializer, optimizer):
    input_shape = (size, size, 3)
    hidden_layer_1 = 1024
    hidden_layer_2 = 512
    num_classes = 39
    layers = [
        Flatten(input_shape=input_shape),
        Dense(hidden_layer_1, kernel_initializer=initializer, activation='relu'),
        LayerNormalization(),
        Dense(hidden_layer_2, kernel_initializer=initializer, activation='relu'),
        LayerNormalization(),
        Dense(num_classes, activation='softmax', kernel_initializer=initializer)
    ]
    model = tf.keras.Sequential(layers)
    model.compile(
    loss='categorical_crossentropy',
    optimizer=optimizer,
    metrics=['accuracy']
    )
    return model

# %%
optim = {}
#sgd_momentum = tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9, nesterov=False)
#optim['sgd_momentum'] = sgd_momentum
adam = tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07)
optim['adam'] = adam
initializer = tf.keras.initializers.HeNormal()

# %%
train_path = '../input/traindata/train_aug'
test_path = '../input/testdata/test'
train_gen = ImageDataGenerator(rescale=1./255, vertical_flip=True, brightness_range=((0.2, 0.8)))
test_gen = ImageDataGenerator(rescale=1./255)
train_generator = train_gen.flow_from_directory(train_path,     
    target_size = (size, size),
    shuffle=True, 
    batch_size=batch_size
)
valid_generator = test_gen.flow_from_directory(test_path,     
    target_size = (size, size),
    shuffle=False, 
    batch_size=batch_size
)
# Out:
# Found 53164 images belonging to 39 classes.
# Found 11104 images belonging to 39 classes.

# %%
def train_model(k, v):
    model = build_model(initializer, v)
    model.summary()
    print('This is a model using:', k)
    model_save = ModelCheckpoint('./ANN_LN_deeper' + k + '.h5',
                                 save_best_only = True, 
                                 save_weights_only = False,
                                 monitor = 'val_loss', 
                                 mode = 'min', verbose = 1)
    milestone = model.fit(train_generator,
              validation_data=valid_generator,
              epochs=epochs,
              steps_per_epoch=train_generator.n//train_generator.batch_size,
              validation_steps = valid_generator.n//valid_generator.batch_size,
              callbacks = [model_save, early_stop, reduce_lr]
              )
    history[k] = milestone

# %%
early_stop = EarlyStopping(monitor = 'val_loss', min_delta = 0.001, 
                               patience = 5, mode = 'min', verbose = 1,
                               restore_best_weights = True)
reduce_lr = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.2, 
                                      patience = 2, min_delta = 0.001, 
                                      mode = 'min', verbose = 1)

for k, v in optim.items():
    train_model(k, v)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 196608)            0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              201327616
# _________________________________________________________________
# layer_normalization (LayerNo (None, 1024)              2048
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# layer_normalization_1 (Layer (None, 512)               1024
# _________________________________________________________________
# dense_2 (Dense)              (None, 39)                20007
# =================================================================
# Total params: 201,875,495
# Trainable params: 201,875,495
# Non-trainable params: 0
# _________________________________________________________________
# This is a model using: adam
# Epoch 1/40
# 415/415 [==============================] - 710s 2s/step - loss: 3.4623 - accuracy: 0.1367 - val_loss: 2.2223 - val_accuracy: 0.3942
#
# Epoch 00001: val_loss improved from inf to 2.22229, saving model to ./ANN_LN_deeperadam.h5
# Epoch 2/40
# 415/415 [==============================] - 308s 742ms/step - loss: 2.1592 - accuracy: 0.3858 - val_loss: 1.6697 - val_accuracy: 0.5190
#
# Epoch 00002: val_loss improved from 2.22229 to 1.66965, saving model to ./ANN_LN_deeperadam.h5
# Epoch 3/40
# 415/415 [==============================] - 338s 814ms/step - loss: 1.6628 - accuracy: 0.5075 - val_loss: 1.3846 - val_accuracy: 0.5896
#
# Epoch 00003: val_loss improved from 1.66965 to 1.38463, saving model to ./ANN_LN_deeperadam.h5
# Epoch 4/40
# 415/415 [==============================] - 340s 819ms/step - loss: 1.4348 - accuracy: 0.5693 - val_loss: 1.1825 - val_accuracy: 0.6461
#
# Epoch 00004: val_loss improved from 1.38463 to 1.18252, saving model to ./ANN_LN_deeperadam.h5
# Epoch 5/40
# 415/415 [==============================] - 340s 818ms/step - loss: 1.2572 - accuracy: 0.6185 - val_loss: 1.1167 - val_accuracy: 0.6641
#
# Epoch 00005: val_loss improved from 1.18252 to 1.11674, saving model to ./ANN_LN_deeperadam.h5
# Epoch 6/40
# 415/415 [==============================] - 341s 822ms/step - loss: 1.1281 - accuracy: 0.6546 - val_loss: 1.0173 - val_accuracy: 0.6919
#
# Epoch 00006: val_loss improved from 1.11674 to 1.01729, saving model to ./ANN_LN_deeperadam.h5
# Epoch 7/40
# 415/415 [==============================] - 339s 816ms/step - loss: 1.0447 - accuracy: 0.6762 - val_loss: 0.9556 - val_accuracy: 0.7088
#
# Epoch 00007: val_loss improved from 1.01729 to 0.95560, saving model to ./ANN_LN_deeperadam.h5
# Epoch 8/40
# 415/415 [==============================] - 340s 820ms/step - loss: 0.9768 - accuracy: 0.6994 - val_loss: 0.8731 - val_accuracy: 0.7313
#
# Epoch 00008: val_loss improved from 0.95560 to 0.87307, saving model to ./ANN_LN_deeperadam.h5
# Epoch 9/40
# 415/415 [==============================] - 344s 829ms/step - loss: 0.8951 - accuracy: 0.7226 - val_loss: 0.9018 - val_accuracy: 0.7246
#
# Epoch 00009: val_loss did not improve from 0.87307
# Epoch 10/40
# 415/415 [==============================] - 335s 807ms/step - loss: 0.8630 - accuracy: 0.7311 - val_loss: 0.8607 - val_accuracy: 0.7376
#
# Epoch 00010: val_loss improved from 0.87307 to 0.86073, saving model to ./ANN_LN_deeperadam.h5
# Epoch 11/40
# 415/415 [==============================] - 348s 840ms/step - loss: 0.8132 - accuracy: 0.7442 - val_loss: 0.7680 - val_accuracy: 0.7623
#
# Epoch 00011: val_loss improved from 0.86073 to 0.76802, saving model to ./ANN_LN_deeperadam.h5
# Epoch 12/40
# 415/415 [==============================] - 349s 840ms/step - loss: 0.7797 - accuracy: 0.7540 - val_loss: 0.9332 - val_accuracy: 0.7131
#
# Epoch 00012: val_loss did not improve from 0.76802
# Epoch 13/40
# 415/415 [==============================] - 340s 819ms/step - loss: 0.7442 - accuracy: 0.7664 - val_loss: 0.7479 - val_accuracy: 0.7642
#
# Epoch 00013: val_loss improved from 0.76802 to 0.74787, saving model to ./ANN_LN_deeperadam.h5
# Epoch 14/40
# 415/415 [==============================] - 347s 837ms/step - loss: 0.7156 - accuracy: 0.7725 - val_loss: 0.7031 - val_accuracy: 0.7807
#
# Epoch 00014: val_loss improved from 0.74787 to 0.70314, saving model to ./ANN_LN_deeperadam.h5
# Epoch 15/40
# 415/415 [==============================] - 348s 840ms/step - loss: 0.6968 - accuracy: 0.7811 - val_loss: 0.6938 - val_accuracy: 0.7813
#
# Epoch 00015: val_loss improved from 0.70314 to 0.69382, saving model to ./ANN_LN_deeperadam.h5
# Epoch 16/40
# 415/415 [==============================] - 347s 836ms/step - loss: 0.6512 - accuracy: 0.7913 - val_loss: 0.6876 - val_accuracy: 0.7835
#
# Epoch 00016: val_loss improved from 0.69382 to 0.68759, saving model to ./ANN_LN_deeperadam.h5
# Epoch 17/40
# 415/415 [==============================] - 349s 842ms/step - loss: 0.6190 - accuracy: 0.8005 - val_loss: 0.6724 - val_accuracy: 0.7852
#
# Epoch 00017: val_loss improved from 0.68759 to 0.67236, saving model to ./ANN_LN_deeperadam.h5
# Epoch 18/40
# 415/415 [==============================] - 349s 842ms/step - loss: 0.6090 - accuracy: 0.8020 - val_loss: 0.6354 - val_accuracy: 0.8028
#
# Epoch 00018: val_loss improved from 0.67236 to 0.63539, saving model to ./ANN_LN_deeperadam.h5
# Epoch 19/40
# 415/415 [==============================] - 346s 833ms/step - loss: 0.5801 - accuracy: 0.8125 - val_loss: 0.6713 - val_accuracy: 0.7908
#
# Epoch 00019: val_loss did not improve from 0.63539
# Epoch 20/40
# 415/415 [==============================] - 336s 810ms/step - loss: 0.5609 - accuracy: 0.8152 - val_loss: 0.6112 - val_accuracy: 0.8092
#
# Epoch 00020: val_loss improved from 0.63539 to 0.61118, saving model to ./ANN_LN_deeperadam.h5
# Epoch 21/40
# 415/415 [==============================] - 343s 827ms/step - loss: 0.5237 - accuracy: 0.8290 - val_loss: 0.6347 - val_accuracy: 0.8004
#
# Epoch 00021: val_loss did not improve from 0.61118
# Epoch 22/40
# 415/415 [==============================] - 340s 819ms/step - loss: 0.4910 - accuracy: 0.8412 - val_loss: 0.6457 - val_accuracy: 0.7987
#
# Epoch 00022: val_loss did not improve from 0.61118
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 23/40
# 415/415 [==============================] - 339s 817ms/step - loss: 0.3966 - accuracy: 0.8724 - val_loss: 0.5274 - val_accuracy: 0.8359
#
# Epoch 00023: val_loss improved from 0.61118 to 0.52745, saving model to ./ANN_LN_deeperadam.h5
# Epoch 24/40
# 415/415 [==============================] - 345s 832ms/step - loss: 0.3701 - accuracy: 0.8827 - val_loss: 0.5290 - val_accuracy: 0.8360
#
# Epoch 00024: val_loss did not improve from 0.52745
# Epoch 25/40
# 415/415 [==============================] - 337s 811ms/step - loss: 0.3633 - accuracy: 0.8855 - val_loss: 0.5391 - val_accuracy: 0.8322
#
# Epoch 00025: val_loss did not improve from 0.52745
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 26/40
# 415/415 [==============================] - 338s 815ms/step - loss: 0.3386 - accuracy: 0.8950 - val_loss: 0.5117 - val_accuracy: 0.8401
#
# Epoch 00026: val_loss improved from 0.52745 to 0.51171, saving model to ./ANN_LN_deeperadam.h5
# Epoch 27/40
# 415/415 [==============================] - 351s 846ms/step - loss: 0.3283 - accuracy: 0.8989 - val_loss: 0.5144 - val_accuracy: 0.8404
#
# Epoch 00027: val_loss did not improve from 0.51171
# Epoch 28/40
# 415/415 [==============================] - 343s 825ms/step - loss: 0.3210 - accuracy: 0.9006 - val_loss: 0.5147 - val_accuracy: 0.8404
#
# Epoch 00028: val_loss did not improve from 0.51171
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 29/40
# 415/415 [==============================] - 343s 825ms/step - loss: 0.3165 - accuracy: 0.9039 - val_loss: 0.5102 - val_accuracy: 0.8410
#
# Epoch 00029: val_loss improved from 0.51171 to 0.51019, saving model to ./ANN_LN_deeperadam.h5
# Epoch 30/40
# 415/415 [==============================] - 351s 845ms/step - loss: 0.3249 - accuracy: 0.9008 - val_loss: 0.5116 - val_accuracy: 0.8392
#
# Epoch 00030: val_loss did not improve from 0.51019
# Epoch 31/40
# 415/415 [==============================] - 345s 831ms/step - loss: 0.3147 - accuracy: 0.9058 - val_loss: 0.5097 - val_accuracy: 0.8424
#
# Epoch 00031: val_loss improved from 0.51019 to 0.50969, saving model to ./ANN_LN_deeperadam.h5
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# Epoch 32/40
# 415/415 [==============================] - 348s 838ms/step - loss: 0.3150 - accuracy: 0.9036 - val_loss: 0.5095 - val_accuracy: 0.8412
#
# Epoch 00032: val_loss improved from 0.50969 to 0.50948, saving model to ./ANN_LN_deeperadam.h5
# Epoch 33/40
# 415/415 [==============================] - 349s 840ms/step - loss: 0.3180 - accuracy: 0.9033 - val_loss: 0.5087 - val_accuracy: 0.8417
#
# Epoch 00033: val_loss improved from 0.50948 to 0.50874, saving model to ./ANN_LN_deeperadam.h5
# Epoch 34/40
# 415/415 [==============================] - 356s 859ms/step - loss: 0.3162 - accuracy: 0.9038 - val_loss: 0.5092 - val_accuracy: 0.8412
#
# Epoch 00034: val_loss did not improve from 0.50874
# Epoch 35/40
# 415/415 [==============================] - 348s 839ms/step - loss: 0.3205 - accuracy: 0.9021 - val_loss: 0.5095 - val_accuracy: 0.8409
#
# Epoch 00035: val_loss did not improve from 0.50874
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# Epoch 36/40
# 415/415 [==============================] - 347s 837ms/step - loss: 0.3192 - accuracy: 0.9025 - val_loss: 0.5093 - val_accuracy: 0.8411
#
# Epoch 00036: val_loss did not improve from 0.50874
# Epoch 37/40
# 415/415 [==============================] - 343s 826ms/step - loss: 0.3111 - accuracy: 0.9039 - val_loss: 0.5092 - val_accuracy: 0.8414
#
# Epoch 00037: val_loss did not improve from 0.50874
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# Epoch 38/40
# 415/415 [==============================] - 346s 833ms/step - loss: 0.3191 - accuracy: 0.9017 - val_loss: 0.5092 - val_accuracy: 0.8414
#
# Epoch 00038: val_loss did not improve from 0.50874
# Restoring model weights from the end of the best epoch.
# Epoch 00038: early stopping

# %%
#Drawing
plt.subplot(4, 1, 1)
plt.title('Training loss')
plt.xlabel('Epoch')

plt.subplot(4, 1, 2)
plt.title('Validation loss')
plt.xlabel('Epoch')

plt.subplot(4, 1, 3)
plt.title('Training accuracy')
plt.xlabel('Epoch')

plt.subplot(4, 1, 4)
plt.title('Validation accuracy')
plt.xlabel('Epoch')

for update_rule, milestone in history.items():
    plt.subplot(4, 1, 1)
    plt.plot(milestone.history['loss'], 'o', label=update_rule)

    plt.subplot(4, 1, 2)
    plt.plot(milestone.history['val_loss'], 'o', label=update_rule)
    plt.subplot(4, 1, 3)
    plt.plot(milestone.history['accuracy'], '-o', label=update_rule)
    
    plt.subplot(4, 1, 4)
    plt.plot(milestone.history['val_accuracy'], '-o', label=update_rule)

for i in [1, 2, 3, 4]:
    plt.subplot(4, 1, i)
    plt.legend(loc='upper center', ncol=4)
plt.gcf().set_size_inches(20, 20)
plt.show()
